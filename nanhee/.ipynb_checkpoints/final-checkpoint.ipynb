# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# !pip install xgboost
# !pip install lightgbm
# !pip install imblearn
# !pip install borutashap
# !pip install eli5

# %%
time_table = pd.read_csv('Survival_time_event.csv', index_col=0)
clinic_table = pd.read_csv('Clinical_Variables.csv', index_col=0)
genetic_table = pd.read_csv('Genetic_alterations.csv', index_col=0)
survival_treatment_table = pd.read_csv('newLabel.csv', index_col=0)

# %%
'''
Correlating numerical features of Time data

- outlier value drop
'''

print('outlier of time: ')
print(time_table.loc[time_table['time'] < 0, 'time'], end='\n\n')

time_table_outlier = time_table.copy()
time_table_outlier.loc[time_table_outlier['time'] < 0, 'time'] = abs(time_table_outlier.loc[time_table_outlier['time'] < 0, 'time'])
print(time_table_outlier.describe(), end='\n\n')
# Out:
# outlier of time:
# 905   -7.945621
# Name: time, dtype: float64
#
#               time        event
# count  1000.000000  1000.000000
# mean     51.876125     0.891000
# std      22.122689     0.311795
# min       7.070708     0.000000
# 25%      37.401307     1.000000
# 50%      47.064712     1.000000
# 75%      60.966476     1.000000
# max     217.078908     1.000000

# %%
'''
Correlating numerical features of Clinic data

- outlier value drop
'''

clinic_table_outlier = clinic_table.copy()

# drop outlier
for col in clinic_table_outlier.columns:
    for outlier in range(10,13):
        clinic_table_outlier = clinic_table_outlier.replace(outlier, 9)

# visualize
for col in clinic_table_outlier.columns:
    print('#', col)
    print(clinic_table_outlier[col].value_counts())
    print('-'*20)
# Out:
# # Var1
# 2    235
# 3    204
# 1    171
# 4    139
# 5     95
# 0     57
# 6     50
# 7     27
# 8     13
# 9      9
# Name: Var1, dtype: int64
# --------------------
# # Var2
# 3    221
# 2    218
# 4    163
# 1    113
# 5    109
# 6     65
# 0     48
# 7     30
# 9     20
# 8     13
# Name: Var2, dtype: int64
# --------------------
# # Var3
# 2    260
# 3    196
# 1    156
# 4    130
# 5     97
# 0     55
# 6     55
# 7     23
# 8     16
# 9     12
# Name: Var3, dtype: int64
# --------------------
# # Var4
# 2    242
# 3    195
# 1    150
# 4    140
# 5    106
# 6     67
# 0     36
# 7     32
# 8     16
# 9     16
# Name: Var4, dtype: int64
# --------------------
# # Var5
# 2    247
# 3    223
# 4    161
# 5    124
# 1     76
# 6     63
# 7     41
# 0     28
# 9     19
# 8     18
# Name: Var5, dtype: int64
# --------------------
# # Var6
# 2    240
# 3    212
# 4    128
# 1    127
# 5     99
# 6     64
# 0     53
# 7     40
# 8     20
# 9     17
# Name: Var6, dtype: int64
# --------------------
# # Var7
# 1    269
# 2    208
# 3    144
# 0    128
# 4    118
# 5     62
# 6     47
# 7     16
# 8      6
# 9      2
# Name: Var7, dtype: int64
# --------------------
# # Var8
# 1    241
# 2    227
# 3    171
# 0    127
# 4    101
# 5     69
# 6     30
# 7     20
# 8     10
# 9      4
# Name: Var8, dtype: int64
# --------------------
# # Var9
# 2    250
# 1    235
# 3    157
# 0    135
# 4    100
# 5     57
# 6     33
# 7     22
# 9      6
# 8      5
# Name: Var9, dtype: int64
# --------------------
# # Var10
# 1    287
# 2    205
# 3    156
# 0    114
# 4    108
# 5     62
# 6     40
# 7     18
# 8      5
# 9      5
# Name: Var10, dtype: int64
# --------------------

# %%
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, ExtraTreesClassifier
from sklearn.metrics import accuracy_score
import lightgbm as lgb

# %%
def TestML(model,selected_genetic):
    
    genetic_10 = genetic_table.copy()
    genetic_10 = genetic_10[selected_genetic]

    input_dataset = pd.concat([survival_treatment_table, time_table_outlier, clinic_table_outlier ,genetic_10], axis=1)
    input_dataset = input_dataset.drop(['event'], axis=1)

    all_index = np.arange(1000)
    train_data, test_data = input_dataset.iloc[all_index[:800],:], input_dataset.iloc[all_index[800:1000],:]
    X_train = train_data.drop(['newlabel'], axis=1)
    Y_train = train_data['newlabel']

    X_test = test_data.drop(['newlabel'], axis=1)
    Y_test = test_data['newlabel']
    
    model.fit(X_train, Y_train)
    acc_log = round(model.score(X_train, Y_train) * 100, 2)
    train_acc = np.round(np.mean(acc_log), 5)
    print('## Train 정확도: ', train_acc)
    
    Y_pred = model.predict(X_test)
    test_acc = np.round(accuracy_score(Y_test, Y_pred), 5)
    print('## Test 정확도: ', test_acc)
    print()
    
    return train_acc, test_acc

# %%
selected_genetic = ['G211', 'G264', 'G179', 'G27', 'G147', 'G139', 'G242', 'G80', 'G263', 'G290']

test_model1 = RandomForestClassifier(n_estimators=200)
TestML(test_model1, selected_genetic)

test_model2 = lgb.LGBMClassifier(n_estimators=30,num_leaves=64,n_jobs=-1,boost_from_average=False)
TestML(test_model2, selected_genetic)
# Out:
# ## Train 정확도:  100.0
# ## Test 정확도:  0.615
#
# ## Train 정확도:  93.25
# ## Test 정확도:  0.635
# (93.25, 0.635)

# %%
genetic = ['G'+str(i) for i in range(1,301)]

# %%
import random

print(random.choices(genetic, k=10))
# Out:
# ['G37', 'G285', 'G72', 'G132', 'G137', 'G102', 'G111', 'G18', 'G139', 'G128']

# %%
over_genetic = []

test_model1 = RandomForestClassifier(n_estimators=200)

for i in range(100):
    test_genetic = random.sample(genetic, 10)
    print('## 임의의 10개 유전자: ', test_genetic)
    train_accuracy, test_accuracy = TestML(test_model1, test_genetic)
    if test_accuracy > 0.615:
        print('-----------------Over!-----------------', end='\n\n\n')
        over_genetic.append(test_genetic)
# Out:
# ## 임의의 10개 유전자:  ['G3', 'G88', 'G87', 'G78', 'G123', 'G143', 'G152', 'G88', 'G143', 'G280']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.57
#
# ## 임의의 10개 유전자:  ['G175', 'G224', 'G126', 'G19', 'G220', 'G70', 'G92', 'G35', 'G241', 'G114']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.57
#
# ## 임의의 10개 유전자:  ['G211', 'G55', 'G285', 'G10', 'G150', 'G236', 'G286', 'G192', 'G258', 'G160']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.58
#
# ## 임의의 10개 유전자:  ['G145', 'G123', 'G69', 'G281', 'G258', 'G246', 'G252', 'G115', 'G27', 'G102']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.595
#
# ## 임의의 10개 유전자:  ['G65', 'G161', 'G188', 'G240', 'G3', 'G137', 'G116', 'G38', 'G154', 'G196']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.55
#
# ## 임의의 10개 유전자:  ['G22', 'G110', 'G14', 'G200', 'G248', 'G161', 'G212', 'G26', 'G262', 'G57']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.59
#
# ## 임의의 10개 유전자:  ['G149', 'G97', 'G103', 'G77', 'G283', 'G79', 'G43', 'G287', 'G288', 'G254']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.57
#
# ## 임의의 10개 유전자:  ['G180', 'G133', 'G77', 'G231', 'G5', 'G281', 'G214', 'G64', 'G76', 'G221']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.575
#
# ## 임의의 10개 유전자:  ['G115', 'G111', 'G125', 'G122', 'G256', 'G194', 'G118', 'G192', 'G286', 'G127']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.575
#
# ## 임의의 10개 유전자:  ['G234', 'G99', 'G7', 'G82', 'G36', 'G257', 'G84', 'G99', 'G73', 'G206']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.56
#
# ## 임의의 10개 유전자:  ['G132', 'G224', 'G279', 'G42', 'G70', 'G136', 'G69', 'G239', 'G39', 'G73']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.56
#
# ## 임의의 10개 유전자:  ['G282', 'G195', 'G238', 'G100', 'G204', 'G74', 'G10', 'G190', 'G6', 'G109']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.56
#
# ## 임의의 10개 유전자:  ['G123', 'G14', 'G277', 'G121', 'G141', 'G68', 'G7', 'G287', 'G262', 'G139']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.59
#
# ## 임의의 10개 유전자:  ['G147', 'G298', 'G216', 'G204', 'G84', 'G41', 'G106', 'G257', 'G292', 'G232']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.58
#
# ## 임의의 10개 유전자:  ['G220', 'G284', 'G281', 'G96', 'G166', 'G202', 'G156', 'G12', 'G237', 'G109']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.565
#
# ## 임의의 10개 유전자:  ['G250', 'G52', 'G245', 'G260', 'G12', 'G260', 'G10', 'G74', 'G89', 'G198']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.575
#
# ## 임의의 10개 유전자:  ['G203', 'G267', 'G1', 'G123', 'G293', 'G41', 'G256', 'G221', 'G282', 'G259']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.6
#
# ## 임의의 10개 유전자:  ['G7', 'G247', 'G49', 'G53', 'G30', 'G229', 'G95', 'G196', 'G120', 'G99']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.56
#
# ## 임의의 10개 유전자:  ['G279', 'G179', 'G19', 'G299', 'G241', 'G284', 'G138', 'G47', 'G101', 'G293']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.58
#
# ## 임의의 10개 유전자:  ['G227', 'G199', 'G218', 'G141', 'G17', 'G141', 'G228', 'G156', 'G31', 'G151']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.6
#
# ## 임의의 10개 유전자:  ['G297', 'G111', 'G115', 'G137', 'G248', 'G145', 'G202', 'G48', 'G282', 'G255']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.575
#
# ## 임의의 10개 유전자:  ['G139', 'G230', 'G194', 'G169', 'G135', 'G289', 'G225', 'G100', 'G32', 'G83']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.53
#
# ## 임의의 10개 유전자:  ['G23', 'G77', 'G227', 'G281', 'G143', 'G179', 'G69', 'G284', 'G219', 'G61']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.56
#
# ## 임의의 10개 유전자:  ['G69', 'G267', 'G10', 'G125', 'G261', 'G282', 'G141', 'G197', 'G231', 'G225']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.565
#
# ## 임의의 10개 유전자:  ['G223', 'G231', 'G103', 'G261', 'G19', 'G76', 'G284', 'G295', 'G9', 'G265']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.57
#
# ## 임의의 10개 유전자:  ['G180', 'G52', 'G25', 'G4', 'G45', 'G118', 'G224', 'G77', 'G120', 'G19']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.595
#
# ## 임의의 10개 유전자:  ['G293', 'G135', 'G195', 'G60', 'G248', 'G229', 'G147', 'G171', 'G151', 'G39']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.57
#
# ## 임의의 10개 유전자:  ['G114', 'G181', 'G214', 'G86', 'G93', 'G232', 'G115', 'G261', 'G185', 'G185']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.595
#
# ## 임의의 10개 유전자:  ['G281', 'G238', 'G89', 'G203', 'G237', 'G260', 'G24', 'G109', 'G284', 'G246']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.585
#
# ## 임의의 10개 유전자:  ['G191', 'G172', 'G83', 'G92', 'G29', 'G82', 'G241', 'G228', 'G174', 'G74']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.58
#
# ## 임의의 10개 유전자:  ['G212', 'G276', 'G146', 'G122', 'G22', 'G246', 'G57', 'G41', 'G33', 'G228']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.565
#
# ## 임의의 10개 유전자:  ['G248', 'G280', 'G98', 'G5', 'G116', 'G37', 'G39', 'G31', 'G203', 'G282']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.595
#
# ## 임의의 10개 유전자:  ['G271', 'G171', 'G200', 'G67', 'G295', 'G67', 'G171', 'G27', 'G15', 'G183']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.585
#
# ## 임의의 10개 유전자:  ['G3', 'G213', 'G154', 'G300', 'G253', 'G152', 'G84', 'G293', 'G293', 'G8']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.555
#
# ## 임의의 10개 유전자:  ['G214', 'G156', 'G117', 'G161', 'G212', 'G218', 'G125', 'G276', 'G93', 'G164']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.6
#
# ## 임의의 10개 유전자:  ['G198', 'G283', 'G240', 'G164', 'G133', 'G199', 'G150', 'G148', 'G231', 'G136']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.595
#
# ## 임의의 10개 유전자:  ['G87', 'G168', 'G277', 'G246', 'G159', 'G2', 'G35', 'G258', 'G64', 'G88']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.595
#
# ## 임의의 10개 유전자:  ['G27', 'G127', 'G125', 'G104', 'G36', 'G8', 'G30', 'G230', 'G178', 'G146']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.595
#
# ## 임의의 10개 유전자:  ['G46', 'G118', 'G129', 'G263', 'G265', 'G154', 'G27', 'G268', 'G240', 'G220']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.605
#
# ## 임의의 10개 유전자:  ['G183', 'G150', 'G261', 'G66', 'G139', 'G203', 'G144', 'G260', 'G157', 'G194']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.59
#
# ## 임의의 10개 유전자:  ['G78', 'G98', 'G9', 'G108', 'G201', 'G277', 'G298', 'G56', 'G291', 'G69']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.575
#
# ## 임의의 10개 유전자:  ['G115', 'G114', 'G270', 'G95', 'G25', 'G244', 'G155', 'G1', 'G236', 'G38']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.585
#
# ## 임의의 10개 유전자:  ['G21', 'G38', 'G152', 'G228', 'G71', 'G33', 'G184', 'G3', 'G203', 'G93']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.6
#
# ## 임의의 10개 유전자:  ['G219', 'G91', 'G266', 'G129', 'G220', 'G250', 'G64', 'G32', 'G211', 'G32']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.56
#
# ## 임의의 10개 유전자:  ['G142', 'G118', 'G138', 'G7', 'G254', 'G159', 'G156', 'G122', 'G74', 'G38']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.575
#
# ## 임의의 10개 유전자:  ['G134', 'G221', 'G62', 'G197', 'G70', 'G13', 'G268', 'G182', 'G292', 'G254']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.595
#
# ## 임의의 10개 유전자:  ['G109', 'G282', 'G96', 'G244', 'G72', 'G204', 'G252', 'G271', 'G146', 'G73']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.595
#
# ## 임의의 10개 유전자:  ['G242', 'G204', 'G175', 'G223', 'G134', 'G33', 'G41', 'G11', 'G10', 'G66']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.585
#
# ## 임의의 10개 유전자:  ['G38', 'G257', 'G212', 'G206', 'G110', 'G29', 'G111', 'G233', 'G91', 'G289']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.57
#
# ## 임의의 10개 유전자:  ['G283', 'G198', 'G90', 'G72', 'G235', 'G22', 'G169', 'G289', 'G178', 'G147']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.555
#
# ## 임의의 10개 유전자:  ['G40', 'G264', 'G224', 'G34', 'G109', 'G188', 'G58', 'G72', 'G17', 'G115']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.585
#
# ## 임의의 10개 유전자:  ['G52', 'G158', 'G69', 'G179', 'G16', 'G49', 'G88', 'G124', 'G266', 'G154']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.565
#
# ## 임의의 10개 유전자:  ['G281', 'G137', 'G108', 'G131', 'G213', 'G59', 'G69', 'G54', 'G2', 'G134']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.55
#
# ## 임의의 10개 유전자:  ['G205', 'G71', 'G226', 'G264', 'G232', 'G132', 'G151', 'G54', 'G135', 'G210']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.585
#
# ## 임의의 10개 유전자:  ['G195', 'G59', 'G68', 'G285', 'G240', 'G285', 'G153', 'G213', 'G213', 'G190']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.56
#
# ## 임의의 10개 유전자:  ['G173', 'G10', 'G1', 'G76', 'G165', 'G113', 'G95', 'G101', 'G246', 'G117']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.56
#
# ## 임의의 10개 유전자:  ['G254', 'G273', 'G65', 'G155', 'G169', 'G26', 'G227', 'G62', 'G171', 'G137']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.56
#
# ## 임의의 10개 유전자:  ['G251', 'G117', 'G92', 'G45', 'G262', 'G14', 'G291', 'G25', 'G259', 'G263']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.56
#
# ## 임의의 10개 유전자:  ['G141', 'G187', 'G79', 'G190', 'G6', 'G28', 'G195', 'G272', 'G138', 'G239']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.55
#
# ## 임의의 10개 유전자:  ['G60', 'G294', 'G191', 'G149', 'G222', 'G131', 'G27', 'G276', 'G254', 'G99']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.56
#
# ## 임의의 10개 유전자:  ['G109', 'G223', 'G235', 'G152', 'G31', 'G294', 'G48', 'G174', 'G286', 'G2']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.59
#
# ## 임의의 10개 유전자:  ['G222', 'G94', 'G241', 'G255', 'G118', 'G1', 'G86', 'G184', 'G57', 'G270']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.555
#
# ## 임의의 10개 유전자:  ['G138', 'G102', 'G153', 'G280', 'G38', 'G210', 'G299', 'G36', 'G35', 'G139']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.565
#
# ## 임의의 10개 유전자:  ['G187', 'G34', 'G109', 'G52', 'G235', 'G83', 'G49', 'G114', 'G92', 'G134']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.55
#
# ## 임의의 10개 유전자:  ['G235', 'G3', 'G167', 'G90', 'G11', 'G63', 'G268', 'G100', 'G231', 'G129']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.585
#
# ## 임의의 10개 유전자:  ['G108', 'G285', 'G222', 'G152', 'G89', 'G142', 'G289', 'G216', 'G85', 'G93']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.595
#
# ## 임의의 10개 유전자:  ['G249', 'G138', 'G34', 'G10', 'G105', 'G28', 'G6', 'G203', 'G210', 'G201']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.535
#
# ## 임의의 10개 유전자:  ['G140', 'G129', 'G81', 'G211', 'G16', 'G68', 'G231', 'G297', 'G200', 'G170']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.585
#
# ## 임의의 10개 유전자:  ['G166', 'G237', 'G281', 'G286', 'G109', 'G165', 'G261', 'G268', 'G17', 'G37']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.59
#
# ## 임의의 10개 유전자:  ['G175', 'G192', 'G204', 'G255', 'G137', 'G36', 'G196', 'G57', 'G128', 'G156']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.585
#
# ## 임의의 10개 유전자:  ['G241', 'G15', 'G2', 'G216', 'G43', 'G166', 'G215', 'G22', 'G178', 'G168']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.58
#
# ## 임의의 10개 유전자:  ['G208', 'G87', 'G77', 'G19', 'G119', 'G19', 'G254', 'G196', 'G66', 'G72']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.575
#
# ## 임의의 10개 유전자:  ['G185', 'G164', 'G114', 'G203', 'G170', 'G285', 'G225', 'G163', 'G216', 'G145']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.58
#
# ## 임의의 10개 유전자:  ['G208', 'G158', 'G94', 'G283', 'G154', 'G24', 'G31', 'G300', 'G55', 'G184']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.585
#
# ## 임의의 10개 유전자:  ['G206', 'G99', 'G250', 'G292', 'G197', 'G296', 'G144', 'G163', 'G101', 'G147']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.575
#
# ## 임의의 10개 유전자:  ['G75', 'G286', 'G20', 'G222', 'G176', 'G97', 'G77', 'G189', 'G33', 'G211']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.585
#
# ## 임의의 10개 유전자:  ['G209', 'G39', 'G250', 'G111', 'G6', 'G54', 'G19', 'G44', 'G60', 'G89']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.6
#
# ## 임의의 10개 유전자:  ['G88', 'G54', 'G105', 'G56', 'G143', 'G195', 'G205', 'G194', 'G241', 'G81']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.58
#
# ## 임의의 10개 유전자:  ['G108', 'G207', 'G184', 'G51', 'G54', 'G64', 'G206', 'G283', 'G237', 'G277']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.565
#
# ## 임의의 10개 유전자:  ['G283', 'G194', 'G186', 'G108', 'G229', 'G294', 'G282', 'G245', 'G182', 'G189']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.58
#
# ## 임의의 10개 유전자:  ['G260', 'G208', 'G189', 'G298', 'G82', 'G225', 'G222', 'G91', 'G114', 'G27']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.585
#
# ## 임의의 10개 유전자:  ['G136', 'G38', 'G65', 'G149', 'G100', 'G272', 'G186', 'G114', 'G108', 'G105']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.57
#
# ## 임의의 10개 유전자:  ['G268', 'G200', 'G130', 'G4', 'G151', 'G8', 'G231', 'G54', 'G242', 'G138']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.585
#
# ## 임의의 10개 유전자:  ['G125', 'G95', 'G80', 'G38', 'G246', 'G147', 'G85', 'G71', 'G256', 'G242']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.57
#
# ## 임의의 10개 유전자:  ['G281', 'G300', 'G223', 'G179', 'G281', 'G255', 'G273', 'G82', 'G255', 'G35']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.59
#
# ## 임의의 10개 유전자:  ['G162', 'G93', 'G87', 'G2', 'G267', 'G231', 'G52', 'G20', 'G59', 'G25']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.585
#
# ## 임의의 10개 유전자:  ['G146', 'G145', 'G1', 'G45', 'G222', 'G97', 'G216', 'G256', 'G30', 'G116']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.555
#
# ## 임의의 10개 유전자:  ['G54', 'G83', 'G300', 'G186', 'G122', 'G197', 'G263', 'G44', 'G117', 'G260']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.595
#
# ## 임의의 10개 유전자:  ['G130', 'G258', 'G75', 'G201', 'G181', 'G31', 'G186', 'G184', 'G156', 'G3']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.58
#
# ## 임의의 10개 유전자:  ['G128', 'G84', 'G299', 'G272', 'G228', 'G66', 'G51', 'G10', 'G68', 'G184']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.565
#
# ## 임의의 10개 유전자:  ['G20', 'G292', 'G219', 'G251', 'G123', 'G102', 'G74', 'G193', 'G259', 'G246']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.585
#
# ## 임의의 10개 유전자:  ['G179', 'G189', 'G217', 'G129', 'G130', 'G123', 'G26', 'G147', 'G89', 'G256']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.595
#
# ## 임의의 10개 유전자:  ['G38', 'G104', 'G166', 'G92', 'G134', 'G161', 'G63', 'G168', 'G229', 'G99']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.585
#
# ## 임의의 10개 유전자:  ['G107', 'G227', 'G277', 'G22', 'G111', 'G174', 'G197', 'G185', 'G114', 'G150']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.565
#
# ## 임의의 10개 유전자:  ['G129', 'G174', 'G156', 'G88', 'G229', 'G115', 'G259', 'G235', 'G143', 'G168']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.585
#
# ## 임의의 10개 유전자:  ['G279', 'G203', 'G77', 'G191', 'G107', 'G242', 'G213', 'G144', 'G97', 'G128']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.595
#
# ## 임의의 10개 유전자:  ['G94', 'G42', 'G226', 'G179', 'G159', 'G289', 'G17', 'G14', 'G58', 'G294']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.585
#
# ## 임의의 10개 유전자:  ['G275', 'G222', 'G75', 'G90', 'G163', 'G280', 'G236', 'G96', 'G110', 'G66']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.55
#
# ## 임의의 10개 유전자:  ['G59', 'G29', 'G234', 'G46', 'G71', 'G267', 'G18', 'G81', 'G219', 'G149']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.56
#
# ## 임의의 10개 유전자:  ['G8', 'G182', 'G242', 'G193', 'G256', 'G13', 'G260', 'G167', 'G210', 'G210']
# ## Train 정확도:  100.0
# ## Test 정확도:  0.575

# %%
print(over_genetic)
# Out:
# []

# %%
over_genetic = []
        
test_model2 = lgb.LGBMClassifier(n_estimators=30,num_leaves=64,n_jobs=-1,boost_from_average=False)

for i in range(100):
    test_genetic = random.sample(genetic, 10)
    print('## 임의의 10개 유전자: ', test_genetic)
    train_accuracy, test_accuracy = TestML(test_model2, test_genetic)
    if train_accuracy > 93.25 or test_accuracy > 0.635:
        print('-----------------Over!-----------------', end='\n\n\n')
        if train_accuracy > 93.25 and test_accuracy > 0.635:
            whatover = 'train&test'
        elif train_accuracy > 93.25:
            whatover = 'train'
        elif test_accuracy > 0.635:
            whatover = 'test'
        over_genetic.append([test_genetic,whatover])
# Out:
# ## 임의의 10개 유전자:  ['G51', 'G24', 'G30', 'G235', 'G90', 'G294', 'G180', 'G113', 'G215', 'G28']
# ## Train 정확도:  93.0
# ## Test 정확도:  0.59
#
# ## 임의의 10개 유전자:  ['G166', 'G4', 'G51', 'G246', 'G84', 'G266', 'G275', 'G273', 'G158', 'G264']
# ## Train 정확도:  92.12
# ## Test 정확도:  0.6
#
# ## 임의의 10개 유전자:  ['G128', 'G122', 'G188', 'G181', 'G236', 'G104', 'G89', 'G101', 'G243', 'G78']
# ## Train 정확도:  93.0
# ## Test 정확도:  0.585
#
# ## 임의의 10개 유전자:  ['G200', 'G276', 'G160', 'G289', 'G260', 'G258', 'G118', 'G171', 'G220', 'G270']
# ## Train 정확도:  93.5
# ## Test 정확도:  0.625
#
# -----------------Over!-----------------
#
#
# ## 임의의 10개 유전자:  ['G73', 'G11', 'G187', 'G44', 'G26', 'G89', 'G216', 'G265', 'G191', 'G175']
# ## Train 정확도:  93.25
# ## Test 정확도:  0.605
#
# ## 임의의 10개 유전자:  ['G147', 'G53', 'G3', 'G167', 'G159', 'G266', 'G119', 'G5', 'G41', 'G172']
# ## Train 정확도:  93.88
# ## Test 정확도:  0.605
#
# -----------------Over!-----------------
#
#
# ## 임의의 10개 유전자:  ['G300', 'G6', 'G80', 'G95', 'G68', 'G191', 'G245', 'G287', 'G16', 'G114']
# ## Train 정확도:  93.5
# ## Test 정확도:  0.6
#
# -----------------Over!-----------------
#
#
# ## 임의의 10개 유전자:  ['G59', 'G107', 'G260', 'G76', 'G299', 'G163', 'G253', 'G230', 'G114', 'G235']
# ## Train 정확도:  92.5
# ## Test 정확도:  0.6
#
# ## 임의의 10개 유전자:  ['G193', 'G178', 'G42', 'G185', 'G143', 'G148', 'G291', 'G194', 'G131', 'G170']
# ## Train 정확도:  93.12
# ## Test 정확도:  0.625
#
# ## 임의의 10개 유전자:  ['G232', 'G296', 'G8', 'G170', 'G3', 'G231', 'G82', 'G182', 'G63', 'G156']
# ## Train 정확도:  92.75
# ## Test 정확도:  0.59
#
# ## 임의의 10개 유전자:  ['G204', 'G248', 'G200', 'G86', 'G92', 'G9', 'G163', 'G226', 'G165', 'G293']
# ## Train 정확도:  94.75
# ## Test 정확도:  0.64
#
# -----------------Over!-----------------
#
#
# ## 임의의 10개 유전자:  ['G130', 'G210', 'G83', 'G63', 'G209', 'G46', 'G48', 'G288', 'G297', 'G205']
# ## Train 정확도:  92.25
# ## Test 정확도:  0.62
#
# ## 임의의 10개 유전자:  ['G192', 'G266', 'G201', 'G61', 'G251', 'G229', 'G226', 'G30', 'G258', 'G3']
# ## Train 정확도:  93.25
# ## Test 정확도:  0.595
#
# ## 임의의 10개 유전자:  ['G1', 'G31', 'G197', 'G256', 'G5', 'G113', 'G122', 'G2', 'G163', 'G241']
# ## Train 정확도:  92.5
# ## Test 정확도:  0.61
#
# ## 임의의 10개 유전자:  ['G250', 'G205', 'G128', 'G100', 'G109', 'G56', 'G63', 'G225', 'G201', 'G38']
# ## Train 정확도:  93.25
# ## Test 정확도:  0.6
#
# ## 임의의 10개 유전자:  ['G62', 'G116', 'G189', 'G82', 'G6', 'G273', 'G213', 'G119', 'G143', 'G175']
# ## Train 정확도:  92.88
# ## Test 정확도:  0.61
#
# ## 임의의 10개 유전자:  ['G167', 'G226', 'G134', 'G45', 'G295', 'G58', 'G232', 'G55', 'G240', 'G181']
# ## Train 정확도:  93.12
# ## Test 정확도:  0.61
#
# ## 임의의 10개 유전자:  ['G264', 'G29', 'G78', 'G14', 'G232', 'G288', 'G151', 'G136', 'G294', 'G144']
# ## Train 정확도:  93.75
# ## Test 정확도:  0.615
#
# -----------------Over!-----------------
#
#
# ## 임의의 10개 유전자:  ['G230', 'G27', 'G46', 'G186', 'G98', 'G165', 'G52', 'G185', 'G77', 'G276']
# ## Train 정확도:  93.0
# ## Test 정확도:  0.595
#
# ## 임의의 10개 유전자:  ['G220', 'G248', 'G70', 'G2', 'G24', 'G17', 'G254', 'G283', 'G3', 'G153']
# ## Train 정확도:  93.0
# ## Test 정확도:  0.625
#
# ## 임의의 10개 유전자:  ['G151', 'G260', 'G239', 'G20', 'G125', 'G188', 'G195', 'G219', 'G64', 'G160']
# ## Train 정확도:  93.5
# ## Test 정확도:  0.585
#
# -----------------Over!-----------------
#
#
# ## 임의의 10개 유전자:  ['G104', 'G216', 'G116', 'G157', 'G3', 'G281', 'G127', 'G250', 'G178', 'G235']
# ## Train 정확도:  93.5
# ## Test 정확도:  0.62
#
# -----------------Over!-----------------
#
#
# ## 임의의 10개 유전자:  ['G200', 'G296', 'G77', 'G134', 'G11', 'G204', 'G23', 'G181', 'G262', 'G280']
# ## Train 정확도:  92.25
# ## Test 정확도:  0.62
#
# ## 임의의 10개 유전자:  ['G213', 'G12', 'G153', 'G282', 'G216', 'G66', 'G284', 'G190', 'G11', 'G257']
# ## Train 정확도:  92.5
# ## Test 정확도:  0.595
#
# ## 임의의 10개 유전자:  ['G60', 'G129', 'G33', 'G214', 'G164', 'G252', 'G122', 'G295', 'G143', 'G205']
# ## Train 정확도:  92.88
# ## Test 정확도:  0.615
#
# ## 임의의 10개 유전자:  ['G184', 'G112', 'G235', 'G255', 'G253', 'G225', 'G126', 'G17', 'G88', 'G254']
# ## Train 정확도:  92.5
# ## Test 정확도:  0.59
#
# ## 임의의 10개 유전자:  ['G248', 'G68', 'G133', 'G76', 'G190', 'G258', 'G146', 'G46', 'G208', 'G213']
# ## Train 정확도:  92.75
# ## Test 정확도:  0.6
#
# ## 임의의 10개 유전자:  ['G97', 'G244', 'G104', 'G152', 'G117', 'G126', 'G105', 'G95', 'G120', 'G225']
# ## Train 정확도:  92.88
# ## Test 정확도:  0.62
#
# ## 임의의 10개 유전자:  ['G252', 'G89', 'G270', 'G249', 'G58', 'G30', 'G66', 'G149', 'G146', 'G142']
# ## Train 정확도:  92.62
# ## Test 정확도:  0.61
#
# ## 임의의 10개 유전자:  ['G151', 'G139', 'G284', 'G41', 'G97', 'G195', 'G263', 'G50', 'G170', 'G34']
# ## Train 정확도:  93.62
# ## Test 정확도:  0.6
#
# -----------------Over!-----------------
#
#
# ## 임의의 10개 유전자:  ['G39', 'G76', 'G216', 'G225', 'G299', 'G85', 'G40', 'G3', 'G120', 'G214']
# ## Train 정확도:  92.38
# ## Test 정확도:  0.575
#
# ## 임의의 10개 유전자:  ['G245', 'G144', 'G44', 'G269', 'G51', 'G152', 'G273', 'G93', 'G238', 'G113']
# ## Train 정확도:  92.88
# ## Test 정확도:  0.61
#
# ## 임의의 10개 유전자:  ['G297', 'G75', 'G64', 'G93', 'G106', 'G127', 'G112', 'G15', 'G240', 'G220']
# ## Train 정확도:  94.0
# ## Test 정확도:  0.595
#
# -----------------Over!-----------------
#
#
# ## 임의의 10개 유전자:  ['G224', 'G254', 'G92', 'G286', 'G61', 'G9', 'G211', 'G227', 'G220', 'G41']
# ## Train 정확도:  94.0
# ## Test 정확도:  0.61
#
# -----------------Over!-----------------
#
#
# ## 임의의 10개 유전자:  ['G145', 'G81', 'G55', 'G111', 'G30', 'G41', 'G136', 'G156', 'G290', 'G17']
# ## Train 정확도:  93.38
# ## Test 정확도:  0.59
#
# -----------------Over!-----------------
#
#
# ## 임의의 10개 유전자:  ['G175', 'G30', 'G29', 'G206', 'G255', 'G39', 'G13', 'G67', 'G57', 'G266']
# ## Train 정확도:  93.0
# ## Test 정확도:  0.585
#
# ## 임의의 10개 유전자:  ['G145', 'G230', 'G254', 'G217', 'G122', 'G7', 'G62', 'G131', 'G194', 'G53']
# ## Train 정확도:  93.5
# ## Test 정확도:  0.6
#
# -----------------Over!-----------------
#
#
# ## 임의의 10개 유전자:  ['G183', 'G173', 'G64', 'G126', 'G229', 'G139', 'G284', 'G150', 'G97', 'G30']
# ## Train 정확도:  94.38
# ## Test 정확도:  0.615
#
# -----------------Over!-----------------
#
#
# ## 임의의 10개 유전자:  ['G236', 'G208', 'G202', 'G60', 'G6', 'G62', 'G88', 'G206', 'G165', 'G280']
# ## Train 정확도:  93.62
# ## Test 정확도:  0.585
#
# -----------------Over!-----------------
#
#
# ## 임의의 10개 유전자:  ['G43', 'G187', 'G45', 'G179', 'G7', 'G278', 'G149', 'G103', 'G229', 'G143']
# ## Train 정확도:  92.38
# ## Test 정확도:  0.615
#
# ## 임의의 10개 유전자:  ['G151', 'G161', 'G109', 'G88', 'G209', 'G217', 'G115', 'G285', 'G126', 'G240']
# ## Train 정확도:  93.5
# ## Test 정확도:  0.625
#
# -----------------Over!-----------------
#
#
# ## 임의의 10개 유전자:  ['G236', 'G124', 'G174', 'G35', 'G26', 'G92', 'G119', 'G22', 'G235', 'G260']
# ## Train 정확도:  93.12
# ## Test 정확도:  0.635
#
# ## 임의의 10개 유전자:  ['G7', 'G234', 'G167', 'G129', 'G176', 'G226', 'G2', 'G133', 'G45', 'G74']
# ## Train 정확도:  93.38
# ## Test 정확도:  0.6
#
# -----------------Over!-----------------
#
#
# ## 임의의 10개 유전자:  ['G146', 'G241', 'G201', 'G27', 'G176', 'G276', 'G3', 'G216', 'G259', 'G35']
# ## Train 정확도:  92.5
# ## Test 정확도:  0.615
#
# ## 임의의 10개 유전자:  ['G41', 'G157', 'G129', 'G39', 'G65', 'G174', 'G261', 'G197', 'G145', 'G10']
# ## Train 정확도:  92.75
# ## Test 정확도:  0.625
#
# ## 임의의 10개 유전자:  ['G96', 'G15', 'G104', 'G87', 'G133', 'G110', 'G56', 'G123', 'G124', 'G74']
# ## Train 정확도:  93.12
# ## Test 정확도:  0.615
#
# ## 임의의 10개 유전자:  ['G178', 'G175', 'G287', 'G54', 'G204', 'G153', 'G265', 'G37', 'G259', 'G73']
# ## Train 정확도:  92.12
# ## Test 정확도:  0.63
#
# ## 임의의 10개 유전자:  ['G62', 'G200', 'G235', 'G261', 'G71', 'G97', 'G57', 'G110', 'G51', 'G9']
# ## Train 정확도:  93.0
# ## Test 정확도:  0.615
#
# ## 임의의 10개 유전자:  ['G59', 'G93', 'G260', 'G27', 'G225', 'G145', 'G64', 'G123', 'G130', 'G29']
# ## Train 정확도:  92.38
# ## Test 정확도:  0.585
#
# ## 임의의 10개 유전자:  ['G65', 'G168', 'G290', 'G297', 'G155', 'G249', 'G184', 'G48', 'G245', 'G284']
# ## Train 정확도:  92.88
# ## Test 정확도:  0.62
#
# ## 임의의 10개 유전자:  ['G260', 'G88', 'G170', 'G80', 'G173', 'G212', 'G144', 'G279', 'G169', 'G125']
# ## Train 정확도:  93.88
# ## Test 정확도:  0.605
#
# -----------------Over!-----------------
#
#
# ## 임의의 10개 유전자:  ['G191', 'G259', 'G63', 'G143', 'G48', 'G246', 'G275', 'G131', 'G150', 'G56']
# ## Train 정확도:  93.75
# ## Test 정확도:  0.61
#
# -----------------Over!-----------------
#
#
# ## 임의의 10개 유전자:  ['G257', 'G10', 'G191', 'G98', 'G168', 'G92', 'G212', 'G150', 'G272', 'G182']
# ## Train 정확도:  93.88
# ## Test 정확도:  0.57
#
# -----------------Over!-----------------
#
#
# ## 임의의 10개 유전자:  ['G110', 'G275', 'G242', 'G234', 'G52', 'G278', 'G300', 'G298', 'G241', 'G195']
# ## Train 정확도:  93.25
# ## Test 정확도:  0.605
#
# ## 임의의 10개 유전자:  ['G164', 'G190', 'G167', 'G295', 'G77', 'G158', 'G74', 'G234', 'G186', 'G166']
# ## Train 정확도:  93.25
# ## Test 정확도:  0.585
#
# ## 임의의 10개 유전자:  ['G225', 'G118', 'G150', 'G24', 'G131', 'G188', 'G155', 'G29', 'G204', 'G139']
# ## Train 정확도:  93.75
# ## Test 정확도:  0.58
#
# -----------------Over!-----------------
#
#
# ## 임의의 10개 유전자:  ['G198', 'G17', 'G192', 'G181', 'G287', 'G156', 'G115', 'G121', 'G294', 'G183']
# ## Train 정확도:  94.0
# ## Test 정확도:  0.605
#
# -----------------Over!-----------------
#
#
# ## 임의의 10개 유전자:  ['G216', 'G83', 'G182', 'G244', 'G119', 'G177', 'G128', 'G277', 'G91', 'G35']
# ## Train 정확도:  94.38
# ## Test 정확도:  0.6
#
# -----------------Over!-----------------
#
#
# ## 임의의 10개 유전자:  ['G297', 'G263', 'G209', 'G275', 'G248', 'G225', 'G163', 'G293', 'G130', 'G66']
# ## Train 정확도:  92.5
# ## Test 정확도:  0.61
#
# ## 임의의 10개 유전자:  ['G33', 'G113', 'G77', 'G8', 'G285', 'G167', 'G209', 'G10', 'G156', 'G104']
# ## Train 정확도:  92.75
# ## Test 정확도:  0.62
#
# ## 임의의 10개 유전자:  ['G223', 'G11', 'G23', 'G97', 'G54', 'G102', 'G126', 'G76', 'G83', 'G255']
# ## Train 정확도:  92.0
# ## Test 정확도:  0.615
#
# ## 임의의 10개 유전자:  ['G253', 'G142', 'G213', 'G199', 'G119', 'G166', 'G70', 'G98', 'G209', 'G242']
# ## Train 정확도:  92.38
# ## Test 정확도:  0.61
#
# ## 임의의 10개 유전자:  ['G28', 'G188', 'G276', 'G89', 'G260', 'G285', 'G207', 'G88', 'G144', 'G1']
# ## Train 정확도:  93.75
# ## Test 정확도:  0.59
#
# -----------------Over!-----------------
#
#
# ## 임의의 10개 유전자:  ['G208', 'G122', 'G30', 'G6', 'G164', 'G147', 'G165', 'G268', 'G286', 'G79']
# ## Train 정확도:  94.62
# ## Test 정확도:  0.605
#
# -----------------Over!-----------------
#
#
# ## 임의의 10개 유전자:  ['G181', 'G295', 'G187', 'G253', 'G292', 'G152', 'G130', 'G127', 'G243', 'G21']
# ## Train 정확도:  92.25
# ## Test 정확도:  0.595
#
# ## 임의의 10개 유전자:  ['G125', 'G285', 'G12', 'G268', 'G107', 'G251', 'G213', 'G100', 'G106', 'G44']
# ## Train 정확도:  93.62
# ## Test 정확도:  0.63
#
# -----------------Over!-----------------
#
#
# ## 임의의 10개 유전자:  ['G166', 'G152', 'G290', 'G161', 'G138', 'G143', 'G123', 'G60', 'G259', 'G117']
# ## Train 정확도:  92.88
# ## Test 정확도:  0.62
#
# ## 임의의 10개 유전자:  ['G245', 'G150', 'G130', 'G78', 'G146', 'G263', 'G297', 'G22', 'G55', 'G153']
# ## Train 정확도:  93.25
# ## Test 정확도:  0.63
#
# ## 임의의 10개 유전자:  ['G27', 'G18', 'G244', 'G226', 'G197', 'G245', 'G243', 'G157', 'G224', 'G191']
# ## Train 정확도:  92.88
# ## Test 정확도:  0.615
#
# ## 임의의 10개 유전자:  ['G32', 'G261', 'G208', 'G30', 'G210', 'G28', 'G2', 'G269', 'G198', 'G153']
# ## Train 정확도:  92.38
# ## Test 정확도:  0.595
#
# ## 임의의 10개 유전자:  ['G8', 'G154', 'G295', 'G267', 'G206', 'G3', 'G244', 'G114', 'G228', 'G165']
# ## Train 정확도:  93.38
# ## Test 정확도:  0.62
#
# -----------------Over!-----------------
#
#
# ## 임의의 10개 유전자:  ['G225', 'G17', 'G232', 'G260', 'G202', 'G192', 'G265', 'G39', 'G221', 'G297']
# ## Train 정확도:  93.75
# ## Test 정확도:  0.6
#
# -----------------Over!-----------------
#
#
# ## 임의의 10개 유전자:  ['G1', 'G102', 'G90', 'G75', 'G275', 'G46', 'G138', 'G172', 'G78', 'G167']
# ## Train 정확도:  92.75
# ## Test 정확도:  0.625
#
# ## 임의의 10개 유전자:  ['G272', 'G275', 'G73', 'G2', 'G149', 'G107', 'G18', 'G204', 'G143', 'G259']
# ## Train 정확도:  92.62
# ## Test 정확도:  0.625
#
# ## 임의의 10개 유전자:  ['G299', 'G95', 'G154', 'G204', 'G192', 'G66', 'G75', 'G186', 'G109', 'G131']
# ## Train 정확도:  93.25
# ## Test 정확도:  0.61
#
# ## 임의의 10개 유전자:  ['G55', 'G75', 'G16', 'G154', 'G193', 'G49', 'G64', 'G42', 'G249', 'G242']
# ## Train 정확도:  93.12
# ## Test 정확도:  0.595
#
# ## 임의의 10개 유전자:  ['G203', 'G8', 'G232', 'G223', 'G94', 'G146', 'G188', 'G216', 'G248', 'G255']
# ## Train 정확도:  93.75
# ## Test 정확도:  0.605
#
# -----------------Over!-----------------
#
#
# ## 임의의 10개 유전자:  ['G234', 'G9', 'G83', 'G153', 'G300', 'G90', 'G216', 'G35', 'G288', 'G16']
# ## Train 정확도:  93.0
# ## Test 정확도:  0.605
#
# ## 임의의 10개 유전자:  ['G184', 'G149', 'G165', 'G114', 'G277', 'G140', 'G216', 'G261', 'G282', 'G102']
# ## Train 정확도:  94.25
# ## Test 정확도:  0.6
#
# -----------------Over!-----------------
#
#
# ## 임의의 10개 유전자:  ['G228', 'G178', 'G11', 'G121', 'G32', 'G23', 'G29', 'G19', 'G12', 'G22']
# ## Train 정확도:  93.12
# ## Test 정확도:  0.61
#
# ## 임의의 10개 유전자:  ['G45', 'G74', 'G113', 'G66', 'G125', 'G254', 'G256', 'G219', 'G292', 'G300']
# ## Train 정확도:  92.25
# ## Test 정확도:  0.63
#
# ## 임의의 10개 유전자:  ['G296', 'G258', 'G100', 'G17', 'G91', 'G19', 'G14', 'G269', 'G189', 'G264']
# ## Train 정확도:  92.5
# ## Test 정확도:  0.63
#
# ## 임의의 10개 유전자:  ['G188', 'G268', 'G80', 'G12', 'G176', 'G17', 'G39', 'G107', 'G52', 'G187']
# ## Train 정확도:  93.5
# ## Test 정확도:  0.615
#
# -----------------Over!-----------------
#
#
# ## 임의의 10개 유전자:  ['G148', 'G151', 'G230', 'G248', 'G226', 'G96', 'G87', 'G296', 'G110', 'G217']
# ## Train 정확도:  93.38
# ## Test 정확도:  0.61
#
# -----------------Over!-----------------
#
#
# ## 임의의 10개 유전자:  ['G113', 'G266', 'G83', 'G198', 'G277', 'G105', 'G126', 'G132', 'G31', 'G296']
# ## Train 정확도:  92.5
# ## Test 정확도:  0.615
#
# ## 임의의 10개 유전자:  ['G148', 'G27', 'G132', 'G281', 'G177', 'G9', 'G248', 'G64', 'G278', 'G154']
# ## Train 정확도:  94.62
# ## Test 정확도:  0.615
#
# -----------------Over!-----------------
#
#
# ## 임의의 10개 유전자:  ['G298', 'G138', 'G74', 'G73', 'G140', 'G98', 'G261', 'G230', 'G244', 'G14']
# ## Train 정확도:  93.12
# ## Test 정확도:  0.615
#
# ## 임의의 10개 유전자:  ['G247', 'G270', 'G294', 'G293', 'G227', 'G165', 'G122', 'G33', 'G275', 'G58']
# ## Train 정확도:  93.5
# ## Test 정확도:  0.595
#
# -----------------Over!-----------------
#
#
# ## 임의의 10개 유전자:  ['G204', 'G223', 'G198', 'G287', 'G10', 'G66', 'G104', 'G178', 'G114', 'G63']
# ## Train 정확도:  93.0
# ## Test 정확도:  0.605
#
# ## 임의의 10개 유전자:  ['G243', 'G136', 'G62', 'G284', 'G77', 'G240', 'G91', 'G272', 'G204', 'G44']
# ## Train 정확도:  93.12
# ## Test 정확도:  0.57
#
# ## 임의의 10개 유전자:  ['G130', 'G192', 'G234', 'G76', 'G274', 'G286', 'G225', 'G180', 'G166', 'G35']
# ## Train 정확도:  93.12
# ## Test 정확도:  0.605
#
# ## 임의의 10개 유전자:  ['G262', 'G160', 'G48', 'G254', 'G123', 'G179', 'G15', 'G73', 'G41', 'G72']
# ## Train 정확도:  93.12
# ## Test 정확도:  0.6
#
# ## 임의의 10개 유전자:  ['G143', 'G224', 'G6', 'G75', 'G151', 'G4', 'G154', 'G123', 'G137', 'G264']
# ## Train 정확도:  93.0
# ## Test 정확도:  0.59
#
# ## 임의의 10개 유전자:  ['G192', 'G232', 'G220', 'G105', 'G258', 'G284', 'G187', 'G37', 'G241', 'G253']
# ## Train 정확도:  92.75
# ## Test 정확도:  0.6
#
# ## 임의의 10개 유전자:  ['G144', 'G33', 'G99', 'G249', 'G294', 'G200', 'G258', 'G243', 'G289', 'G6']
# ## Train 정확도:  93.62
# ## Test 정확도:  0.57
#
# -----------------Over!-----------------
#
#
# ## 임의의 10개 유전자:  ['G217', 'G142', 'G2', 'G226', 'G9', 'G236', 'G175', 'G94', 'G167', 'G118']
# ## Train 정확도:  92.5
# ## Test 정확도:  0.61
#
# ## 임의의 10개 유전자:  ['G77', 'G152', 'G203', 'G84', 'G55', 'G184', 'G162', 'G234', 'G214', 'G47']
# ## Train 정확도:  92.5
# ## Test 정확도:  0.6
#
# ## 임의의 10개 유전자:  ['G136', 'G281', 'G82', 'G271', 'G26', 'G236', 'G253', 'G81', 'G49', 'G259']
# ## Train 정확도:  93.88
# ## Test 정확도:  0.62
#
# -----------------Over!-----------------
#
#
# ## 임의의 10개 유전자:  ['G29', 'G45', 'G78', 'G181', 'G230', 'G137', 'G6', 'G194', 'G168', 'G280']
# ## Train 정확도:  92.25
# ## Test 정확도:  0.59
#
# ## 임의의 10개 유전자:  ['G8', 'G225', 'G187', 'G24', 'G179', 'G229', 'G228', 'G88', 'G257', 'G173']
# ## Train 정확도:  93.12
# ## Test 정확도:  0.59

# %%
print(over_genetic)
print(len(over_genetic))
# Out:
# [[['G200', 'G276', 'G160', 'G289', 'G260', 'G258', 'G118', 'G171', 'G220', 'G270'], 'train'], [['G147', 'G53', 'G3', 'G167', 'G159', 'G266', 'G119', 'G5', 'G41', 'G172'], 'train'], [['G300', 'G6', 'G80', 'G95', 'G68', 'G191', 'G245', 'G287', 'G16', 'G114'], 'train'], [['G204', 'G248', 'G200', 'G86', 'G92', 'G9', 'G163', 'G226', 'G165', 'G293'], 'train&test'], [['G264', 'G29', 'G78', 'G14', 'G232', 'G288', 'G151', 'G136', 'G294', 'G144'], 'train'], [['G151', 'G260', 'G239', 'G20', 'G125', 'G188', 'G195', 'G219', 'G64', 'G160'], 'train'], [['G104', 'G216', 'G116', 'G157', 'G3', 'G281', 'G127', 'G250', 'G178', 'G235'], 'train'], [['G151', 'G139', 'G284', 'G41', 'G97', 'G195', 'G263', 'G50', 'G170', 'G34'], 'train'], [['G297', 'G75', 'G64', 'G93', 'G106', 'G127', 'G112', 'G15', 'G240', 'G220'], 'train'], [['G224', 'G254', 'G92', 'G286', 'G61', 'G9', 'G211', 'G227', 'G220', 'G41'], 'train'], [['G145', 'G81', 'G55', 'G111', 'G30', 'G41', 'G136', 'G156', 'G290', 'G17'], 'train'], [['G145', 'G230', 'G254', 'G217', 'G122', 'G7', 'G62', 'G131', 'G194', 'G53'], 'train'], [['G183', 'G173', 'G64', 'G126', 'G229', 'G139', 'G284', 'G150', 'G97', 'G30'], 'train'], [['G236', 'G208', 'G202', 'G60', 'G6', 'G62', 'G88', 'G206', 'G165', 'G280'], 'train'], [['G151', 'G161', 'G109', 'G88', 'G209', 'G217', 'G115', 'G285', 'G126', 'G240'], 'train'], [['G7', 'G234', 'G167', 'G129', 'G176', 'G226', 'G2', 'G133', 'G45', 'G74'], 'train'], [['G260', 'G88', 'G170', 'G80', 'G173', 'G212', 'G144', 'G279', 'G169', 'G125'], 'train'], [['G191', 'G259', 'G63', 'G143', 'G48', 'G246', 'G275', 'G131', 'G150', 'G56'], 'train'], [['G257', 'G10', 'G191', 'G98', 'G168', 'G92', 'G212', 'G150', 'G272', 'G182'], 'train'], [['G225', 'G118', 'G150', 'G24', 'G131', 'G188', 'G155', 'G29', 'G204', 'G139'], 'train'], [['G198', 'G17', 'G192', 'G181', 'G287', 'G156', 'G115', 'G121', 'G294', 'G183'], 'train'], [['G216', 'G83', 'G182', 'G244', 'G119', 'G177', 'G128', 'G277', 'G91', 'G35'], 'train'], [['G28', 'G188', 'G276', 'G89', 'G260', 'G285', 'G207', 'G88', 'G144', 'G1'], 'train'], [['G208', 'G122', 'G30', 'G6', 'G164', 'G147', 'G165', 'G268', 'G286', 'G79'], 'train'], [['G125', 'G285', 'G12', 'G268', 'G107', 'G251', 'G213', 'G100', 'G106', 'G44'], 'train'], [['G8', 'G154', 'G295', 'G267', 'G206', 'G3', 'G244', 'G114', 'G228', 'G165'], 'train'], [['G225', 'G17', 'G232', 'G260', 'G202', 'G192', 'G265', 'G39', 'G221', 'G297'], 'train'], [['G203', 'G8', 'G232', 'G223', 'G94', 'G146', 'G188', 'G216', 'G248', 'G255'], 'train'], [['G184', 'G149', 'G165', 'G114', 'G277', 'G140', 'G216', 'G261', 'G282', 'G102'], 'train'], [['G188', 'G268', 'G80', 'G12', 'G176', 'G17', 'G39', 'G107', 'G52', 'G187'], 'train'], [['G148', 'G151', 'G230', 'G248', 'G226', 'G96', 'G87', 'G296', 'G110', 'G217'], 'train'], [['G148', 'G27', 'G132', 'G281', 'G177', 'G9', 'G248', 'G64', 'G278', 'G154'], 'train'], [['G247', 'G270', 'G294', 'G293', 'G227', 'G165', 'G122', 'G33', 'G275', 'G58'], 'train'], [['G144', 'G33', 'G99', 'G249', 'G294', 'G200', 'G258', 'G243', 'G289', 'G6'], 'train'], [['G136', 'G281', 'G82', 'G271', 'G26', 'G236', 'G253', 'G81', 'G49', 'G259'], 'train']]
# 35
