# %%
# !pip install xgboost
# !pip install lightgbm
# !pip install imblearn
# !pip install borutashap
# !pip install eli5

import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, ExtraTreesClassifier
from sklearn.metrics import accuracy_score
import lightgbm as lgb
import random


plt.rcParams["figure.figsize"] = (200,10)


'''
###########################################

Load CSV Dataset to DataFrame

###########################################
'''


time_table = pd.read_csv('Survival_time_event.csv', index_col=0)
clinic_table = pd.read_csv('Clinical_Variables.csv', index_col=0)
genetic_table = pd.read_csv('Genetic_alterations.csv', index_col=0)
survival_treatment_table = pd.read_csv('Label.csv', index_col=0)


'''
###########################################

Correlating Numerical Features of Time Data

-  Dropped Outlier Value

###########################################
'''


print('outlier of time: ')
print(time_table.loc[time_table['time'] < 0, 'time'], end='\n\n')

time_table_outlier = time_table.copy()
time_table_outlier.loc[time_table_outlier['time'] < 0, 'time'] = abs(time_table_outlier.loc[time_table_outlier['time'] < 0, 'time'])
print(time_table_outlier.describe(), end='\n\n')


'''
###########################################

Correlating Numerical Features of Clinic Data

-  Dropped Outlier Value

###########################################
'''


clinic_table_outlier = clinic_table.copy()

# drop outlier
for col in clinic_table_outlier.columns:
    for outlier in range(10,13):
        clinic_table_outlier = clinic_table_outlier.replace(outlier, 9)

# visualize
for col in clinic_table_outlier.columns:
    print('#', col)
    print(clinic_table_outlier[col].value_counts())
    print('-'*20)
   

'''
###########################################

Correlating Numerical Features of Clinic Data

- Normalization

###########################################
'''


clinic_table_normalization = clinic_table_outlier.copy()

# normalization
for col in clinic_table_normalization.columns:
    clinic_table_normalization[col] = (clinic_table_normalization[col] + 1)/10.0
    
# visualize
for col in clinic_table_normalization.columns:
    print('#', col)
    print(clinic_table_normalization[col].value_counts())
    print('-'*20)    
    
    
'''
###########################################

Correlating Numerical Features of Genetic Data

- Normalization

###########################################
'''


genetic_table_normalization = genetic_table.copy()

# normalization
for col in genetic_table_normalization.columns:
    genetic_table_normalization[col] -= 0.5
    
    
print(genetic_table_normalization.head(10))


'''
###########################################

Machine Learning Test Function

###########################################
'''

def TestML(model,selected_genetic):
    train_acc = []
    test_acc = []
    for i in range(20):
        genetic_10 = genetic_table_normalization.copy()
        genetic_10 = genetic_10[selected_genetic]

        input_dataset = pd.concat([survival_treatment_table, time_table_outlier, clinic_table_normalization ,genetic_10], axis=1)
        input_dataset = input_dataset.drop(['event'], axis=1)

        all_index = np.arange(1000)
        train_data, test_data = input_dataset.iloc[all_index[:800],:], input_dataset.iloc[all_index[800:1000],:]
        X_train = train_data.drop(['newlabel'], axis=1)
        Y_train = train_data['newlabel']

        X_test = test_data.drop(['newlabel'], axis=1)
        Y_test = test_data['newlabel']

        model.fit(X_train, Y_train)
        train_acc.append(np.round(model.score(X_train, Y_train) * 100, 10))
        
        Y_pred = model.predict(X_test)
        test_acc.append(np.round(accuracy_score(Y_test, Y_pred), 10))
        
        
    print('## Train 정확도: ', np.round(np.max(train_acc), 3), np.round(np.min(train_acc), 3))
    print('## Test 정확도: ', np.round(np.max(test_acc),3), np.round(np.min(test_acc),3))
    print()
    
    return train_acc, test_acc


'''
###########################################

Sorting String Values of Genetic Names Function

###########################################
'''

def sort_genetic_table(genetic_list):
    np_rgl = np.array(genetic_list)
    np_rgl = np.char.replace(np_rgl, 'G', '')
    np_rgl = np.array(np_rgl, dtype='int')
    np_rgl = sorted(np_rgl)
    np_rgl = np.array(np_rgl, dtype='str')
    np_rgl = np.char.add(np.array(['G']*np_rgl.shape[0]),np_rgl)

    return np_rgl.tolist()


'''
###########################################

Selected Genetic Set Test

###########################################
'''


selected_genetic = ['G211', 'G179', 'G80', 'G27', 'G147', 'G139', 'G242', 'G264', 'G290', 'G130']

test_model1 = RandomForestClassifier(n_estimators=60)
test_model2 = lgb.LGBMClassifier(n_estimators=25,num_leaves=64,n_jobs=-1,boost_from_average=False)

print('## test_model1 (Train accuracy가 100인 경우의 모델)')
model1_train, model1_test = TestML(test_model1, selected_genetic)

print('## test_model2 (Train accuracy가 100이 아닌 경우의 모델)')
model2_train, model2_test = TestML(test_model2, selected_genetic)

print(model1_train)
print(model1_test)
print(model2_train)
print(model2_test)

#draw table
model_train_results = np.array([[np.round(np.max(model1_train), 3), np.round(np.min(model1_train), 3)],
                               [np.round(np.max(model1_test), 3),np.round(np.min(model1_test), 3)],
                               [np.round(np.max(model2_train), 3),np.round(np.min(model2_train), 3)],
                               [np.round(np.max(model2_test), 3),np.round(np.min(model2_test), 3)]])

display(pd.DataFrame(model_train_results, columns=['Max', 'Min'],
                     index=['RandomForest Train', 'RandomForest Test','LightGBM Train','LightGBM Test']))
print()
print()

'''
###########################################

Random Genetic Set Test - test_model1: RANDOM FOREST

###########################################
'''


genetic = ['G'+str(i) for i in range(1,301)]


over_genetic = []
random_genetic_list = []

for i in range(100):
    test_genetic = random.sample(genetic, 10)
    print('## 임의의 10개 유전자: ', test_genetic)
    random_genetic_list.extend(test_genetic)
    
    train_accuracy, test_accuracy = TestML(test_model1, test_genetic)

    if np.max(test_accuracy) >= 0.65 or np.min(test_accuracy) >= 0.565:
        print('-----------------Over!-----------------', end='\n\n\n')
        if np.max(test_accuracy) >= 0.65 and np.min(test_accuracy) >= 0.565:
            whatover = 'max&min'
        elif np.max(test_accuracy) >= 0.65:
            whatover = 'max'
        elif np.min(test_accuracy) >= 0.56:
            whatover = 'min'
        over_genetic.append([test_genetic,whatover])

# draw table
print(over_genetic) 

if over_genetic:
    over_genetic_results = np.array(over_genetic)
    pd.set_option('display.max_colwidth', -1)
    display(pd.DataFrame(over_genetic_results, columns=['RandomSet', 'Test Result']))

# draw graph
fig, ax = plt.subplots()

kwargs = dict(alpha=0.3, bins=300)

sorted_random_genetic_list = sort_genetic_table(random_genetic_list)
ax.hist(sorted_random_genetic_list, **dict(alpha=0.3, bins=300), color='r', label='random genetic table')
ax.hist(selected_genetic, **dict(alpha=1, bins=300), color='g', label='selected genetic table')
ax.set(title='Frequency Histogram of Random genetic table', ylabel='Frequency')
fig.savefig('Frequency Histogram of Random genetic table - Acc_100.png', dpi = 200)
plt.show()


'''
###########################################

Random Genetic Set Test - test_model2: LIGHTGBM 

###########################################
'''


over_genetic = []
random_genetic_list = []

for i in range(100):
    test_genetic = random.sample(genetic, 10)
    print('## 임의의 10개 유전자: ', test_genetic)
    random_genetic_list.extend(test_genetic)
    
    train_accuracy, test_accuracy = TestML(test_model2, test_genetic)
    
    if np.max(test_accuracy) >= 0.635:
        print('-----------------Over!-----------------', end='\n\n\n')
        over_genetic.append([test_genetic,np.max(test_accuracy)])

#draw table
print(over_genetic) 

if over_genetic:
    over_genetic_results = np.array(over_genetic)
    pd.set_option('display.max_colwidth', -1)
    display(pd.DataFrame(over_genetic_results, columns=['RandomSet', 'Test Result']))
    

# draw graph
fig, ax = plt.subplots()

kwargs = dict(alpha=0.3, bins=300)

sorted_random_genetic_list = sort_genetic_table(random_genetic_list)
ax.hist(sorted_random_genetic_list, **dict(alpha=0.3, bins=300), color='r', label='random genetic table')
ax.hist(selected_genetic, **dict(alpha=1, bins=300), color='g', label='selected genetic table')
ax.set(title='Frequency Histogram of Random genetic table', ylabel='Frequency')
fig.savefig('Frequency Histogram of Random genetic table - Acc_not_100.png', dpi = 200)
plt.show()

'''
###########################################

ML Feature Selection Test - Genetic Top 10 x 3

###########################################
'''


test_genetic = ['G238', 'G47', 'G290', 'G242', 'G162', 'G130', 'G65', 'G11', 'G300', 'G139']
print('## ML로 뽑은 10개 유전자: ', test_genetic)

model1_train, model1_test = TestML(test_model1, test_genetic)
model2_train, model2_test = TestML(test_model2, test_genetic)


#draw table
model_train_results = np.array([[np.round(np.max(model1_train), 3), np.round(np.min(model1_train), 3)],
                               [np.round(np.max(model1_test), 3),np.round(np.min(model1_test), 3)],
                               [np.round(np.max(model2_train), 3),np.round(np.min(model2_train), 3)],
                               [np.round(np.max(model2_test), 3),np.round(np.min(model2_test), 3)]])

display(pd.DataFrame(model_train_results, columns=['Max', 'Min'],
                     index=['RandomForest Train', 'RandomForest Test','LightGBM Train','LightGBM Test']))


test_genetic = ['G238', 'G191', 'G242', 'G200', 'G130', 'G166', 'G124', 'G57', 'G263', 'G146']
print('## ML로 뽑은 10개 유전자: ', test_genetic)

model1_train, model1_test = TestML(test_model1, test_genetic)
model2_train, model2_test = TestML(test_model2, test_genetic)


#draw table
model_train_results = np.array([[np.round(np.max(model1_train), 3), np.round(np.min(model1_train), 3)],
                               [np.round(np.max(model1_test), 3),np.round(np.min(model1_test), 3)],
                               [np.round(np.max(model2_train), 3),np.round(np.min(model2_train), 3)],
                               [np.round(np.max(model2_test), 3),np.round(np.min(model2_test), 3)]])

display(pd.DataFrame(model_train_results, columns=['Max', 'Min'],
                     index=['RandomForest Train', 'RandomForest Test','LightGBM Train','LightGBM Test']))


test_genetic = ['G200', 'G18', 'G75', 'G6', 'G112', 'G148', 'G284', 'G9', 'G221', 'G187']
print('## ML로 뽑은 10개 유전자: ', test_genetic)

model1_train, model1_test = TestML(test_model1, test_genetic)
model2_train, model2_test = TestML(test_model2, test_genetic)

#draw table
model_train_results = np.array([[np.round(np.max(model1_train), 3), np.round(np.min(model1_train), 3)],
                               [np.round(np.max(model1_test), 3),np.round(np.min(model1_test), 3)],
                               [np.round(np.max(model2_train), 3),np.round(np.min(model2_train), 3)],
                               [np.round(np.max(model2_test), 3),np.round(np.min(model2_test), 3)]])

display(pd.DataFrame(model_train_results, columns=['Max', 'Min'],
                     index=['RandomForest Train', 'RandomForest Test','LightGBM Train','LightGBM Test']))
# Out:
# outlier of time:
# 905   -7.945621
# Name: time, dtype: float64
#
#               time        event
# count  1000.000000  1000.000000
# mean     51.876125     0.891000
# std      22.122689     0.311795
# min       7.070708     0.000000
# 25%      37.401307     1.000000
# 50%      47.064712     1.000000
# 75%      60.966476     1.000000
# max     217.078908     1.000000
#
# # Var1
# 2    235
# 3    204
# 1    171
# 4    139
# 5     95
# 0     57
# 6     50
# 7     27
# 8     13
# 9      9
# Name: Var1, dtype: int64
# --------------------
# # Var2
# 3    221
# 2    218
# 4    163
# 1    113
# 5    109
# 6     65
# 0     48
# 7     30
# 9     20
# 8     13
# Name: Var2, dtype: int64
# --------------------
# # Var3
# 2    260
# 3    196
# 1    156
# 4    130
# 5     97
# 0     55
# 6     55
# 7     23
# 8     16
# 9     12
# Name: Var3, dtype: int64
# --------------------
# # Var4
# 2    242
# 3    195
# 1    150
# 4    140
# 5    106
# 6     67
# 0     36
# 7     32
# 8     16
# 9     16
# Name: Var4, dtype: int64
# --------------------
# # Var5
# 2    247
# 3    223
# 4    161
# 5    124
# 1     76
# 6     63
# 7     41
# 0     28
# 9     19
# 8     18
# Name: Var5, dtype: int64
# --------------------
# # Var6
# 2    240
# 3    212
# 4    128
# 1    127
# 5     99
# 6     64
# 0     53
# 7     40
# 8     20
# 9     17
# Name: Var6, dtype: int64
# --------------------
# # Var7
# 1    269
# 2    208
# 3    144
# 0    128
# 4    118
# 5     62
# 6     47
# 7     16
# 8      6
# 9      2
# Name: Var7, dtype: int64
# --------------------
# # Var8
# 1    241
# 2    227
# 3    171
# 0    127
# 4    101
# 5     69
# 6     30
# 7     20
# 8     10
# 9      4
# Name: Var8, dtype: int64
# --------------------
# # Var9
# 2    250
# 1    235
# 3    157
# 0    135
# 4    100
# 5     57
# 6     33
# 7     22
# 9      6
# 8      5
# Name: Var9, dtype: int64
# --------------------
# # Var10
# 1    287
# 2    205
# 3    156
# 0    114
# 4    108
# 5     62
# 6     40
# 7     18
# 8      5
# 9      5
# Name: Var10, dtype: int64
# --------------------
# # Var1
# 0.3    235
# 0.4    204
# 0.2    171
# 0.5    139
# 0.6     95
# 0.1     57
# 0.7     50
# 0.8     27
# 0.9     13
# 1.0      9
# Name: Var1, dtype: int64
# --------------------
# # Var2
# 0.4    221
# 0.3    218
# 0.5    163
# 0.2    113
# 0.6    109
# 0.7     65
# 0.1     48
# 0.8     30
# 1.0     20
# 0.9     13
# Name: Var2, dtype: int64
# --------------------
# # Var3
# 0.3    260
# 0.4    196
# 0.2    156
# 0.5    130
# 0.6     97
# 0.1     55
# 0.7     55
# 0.8     23
# 0.9     16
# 1.0     12
# Name: Var3, dtype: int64
# --------------------
# # Var4
# 0.3    242
# 0.4    195
# 0.2    150
# 0.5    140
# 0.6    106
# 0.7     67
# 0.1     36
# 0.8     32
# 0.9     16
# 1.0     16
# Name: Var4, dtype: int64
# --------------------
# # Var5
# 0.3    247
# 0.4    223
# 0.5    161
# 0.6    124
# 0.2     76
# 0.7     63
# 0.8     41
# 0.1     28
# 1.0     19
# 0.9     18
# Name: Var5, dtype: int64
# --------------------
# # Var6
# 0.3    240
# 0.4    212
# 0.5    128
# 0.2    127
# 0.6     99
# 0.7     64
# 0.1     53
# 0.8     40
# 0.9     20
# 1.0     17
# Name: Var6, dtype: int64
# --------------------
# # Var7
# 0.2    269
# 0.3    208
# 0.4    144
# 0.1    128
# 0.5    118
# 0.6     62
# 0.7     47
# 0.8     16
# 0.9      6
# 1.0      2
# Name: Var7, dtype: int64
# --------------------
# # Var8
# 0.2    241
# 0.3    227
# 0.4    171
# 0.1    127
# 0.5    101
# 0.6     69
# 0.7     30
# 0.8     20
# 0.9     10
# 1.0      4
# Name: Var8, dtype: int64
# --------------------
# # Var9
# 0.3    250
# 0.2    235
# 0.4    157
# 0.1    135
# 0.5    100
# 0.6     57
# 0.7     33
# 0.8     22
# 1.0      6
# 0.9      5
# Name: Var9, dtype: int64
# --------------------
# # Var10
# 0.2    287
# 0.3    205
# 0.4    156
# 0.1    114
# 0.5    108
# 0.6     62
# 0.7     40
# 0.8     18
# 0.9      5
# 1.0      5
# Name: Var10, dtype: int64
# --------------------
#     G1   G2   G3   G4   G5   G6   G7   G8   G9  G10  ...  G291  G292  G293  \
# 0 -0.5  0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5  ...  -0.5  -0.5  -0.5
# 1 -0.5  0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5  ...  -0.5  -0.5  -0.5
# 2 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5  ...  -0.5  -0.5  -0.5
# 3 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5  0.5 -0.5  0.5  ...  -0.5   0.5  -0.5
# 4 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5  ...  -0.5  -0.5  -0.5
# 5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5  ...  -0.5  -0.5  -0.5
# 6 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5  ...  -0.5  -0.5  -0.5
# 7 -0.5 -0.5 -0.5  0.5 -0.5 -0.5 -0.5 -0.5 -0.5  0.5  ...  -0.5  -0.5  -0.5
# 8 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5  ...  -0.5  -0.5  -0.5
# 9 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5  ...  -0.5  -0.5  -0.5
#
#    G294  G295  G296  G297  G298  G299  G300
# 0  -0.5  -0.5  -0.5  -0.5  -0.5  -0.5  -0.5
# 1  -0.5  -0.5  -0.5  -0.5  -0.5  -0.5  -0.5
# 2  -0.5  -0.5  -0.5  -0.5  -0.5  -0.5  -0.5
# 3   0.5  -0.5  -0.5  -0.5  -0.5  -0.5  -0.5
# 4  -0.5  -0.5  -0.5  -0.5  -0.5  -0.5   0.5
# 5  -0.5  -0.5  -0.5  -0.5  -0.5  -0.5  -0.5
# 6  -0.5  -0.5   0.5  -0.5  -0.5  -0.5  -0.5
# 7  -0.5  -0.5   0.5   0.5  -0.5  -0.5  -0.5
# 8  -0.5  -0.5  -0.5  -0.5  -0.5  -0.5  -0.5
# 9  -0.5  -0.5  -0.5  -0.5  -0.5  -0.5  -0.5
#
# [10 rows x 300 columns]
# ## test_model1 (Train accuracy가 100인 경우의 모델)
# ## Train 정확도:  100.0 100.0
# ## Test 정확도:  0.62 0.55
#
# ## test_model2 (Train accuracy가 100이 아닌 경우의 모델)
# ## Train 정확도:  89.25 89.25
# ## Test 정확도:  0.635 0.635
#
# [100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0]
# [0.555, 0.62, 0.575, 0.56, 0.595, 0.57, 0.585, 0.58, 0.555, 0.585, 0.585, 0.61, 0.61, 0.615, 0.6, 0.575, 0.585, 0.595, 0.585, 0.55]
# [89.25, 89.25, 89.25, 89.25, 89.25, 89.25, 89.25, 89.25, 89.25, 89.25, 89.25, 89.25, 89.25, 89.25, 89.25, 89.25, 89.25, 89.25, 89.25, 89.25]
# [0.635, 0.635, 0.635, 0.635, 0.635, 0.635, 0.635, 0.635, 0.635, 0.635, 0.635, 0.635, 0.635, 0.635, 0.635, 0.635, 0.635, 0.635, 0.635, 0.635]
#                         Max      Min
# RandomForest Train  100.000  100.000
# RandomForest Test     0.620    0.550
# LightGBM Train       89.250   89.250
# LightGBM Test         0.635    0.635
# ## 임의의 10개 유전자:  ['G69', 'G47', 'G59', 'G244', 'G12', 'G300', 'G254', 'G58', 'G79', 'G23']
# ## Train 정확도:  100.0 99.875
# ## Test 정확도:  0.61 0.515
#
# ## 임의의 10개 유전자:  ['G47', 'G82', 'G247', 'G154', 'G266', 'G274', 'G271', 'G20', 'G36', 'G227']
# ## Train 정확도:  100.0 100.0
# ## Test 정확도:  0.635 0.535
#
# ## 임의의 10개 유전자:  ['G80', 'G234', 'G90', 'G193', 'G9', 'G88', 'G153', 'G54', 'G2', 'G210']
# ## Train 정확도:  100.0 100.0
# ## Test 정확도:  0.605 0.535
#
# ## 임의의 10개 유전자:  ['G111', 'G158', 'G77', 'G177', 'G244', 'G148', 'G170', 'G134', 'G103', 'G230']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-6b441818b28b> in <module>
#     235     random_genetic_list.extend(test_genetic)
#     236
# --> 237     train_accuracy, test_accuracy = TestML(test_model1, test_genetic)
#     238
#     239     if np.max(test_accuracy) >= 0.65 or np.min(test_accuracy) >= 0.565:
#
# <ipython-input-3-6b441818b28b> in TestML(model, selected_genetic)
#     147         Y_test = test_data['newlabel']
#     148
# --> 149         model.fit(X_train, Y_train)
#     150         train_acc.append(np.round(model.score(X_train, Y_train) * 100, 10))
#     151
#
# C:\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in fit(self, X, y, sample_weight)
#     386             # since correctness does not rely on using threads.
#     387             trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
# --> 388                              **_joblib_parallel_args(prefer='threads'))(
#     389                 delayed(_parallel_build_trees)(
#     390                     t, self, X, y, sample_weight, i, len(trees),
#
# C:\anaconda3\lib\site-packages\sklearn\utils\fixes.py in _joblib_parallel_args(**kwargs)
#      84     import joblib
#      85
# ---> 86     if parse_version(joblib.__version__) >= parse_version('0.12'):
#      87         return kwargs
#      88
#
# C:\anaconda3\lib\site-packages\pkg_resources\__init__.py in parse_version(v)
#     112 def parse_version(v):
#     113     try:
# --> 114         return packaging.version.Version(v)
#     115     except packaging.version.InvalidVersion:
#     116         return packaging.version.LegacyVersion(v)
#
# C:\anaconda3\lib\site-packages\pkg_resources\_vendor\packaging\version.py in __init__(self, version)
#     274         # Validate the version and parse it into pieces
#     275         match = self._regex.search(version)
# --> 276         if not match:
#     277             raise InvalidVersion("Invalid version: '{0}'".format(version))
#     278
#
# KeyboardInterrupt:

# %%
test_genetic = ['G238', 'G47', 'G290', 'G242', 'G162', 'G130', 'G65', 'G11', 'G300', 'G139']

# %%
test_genetic = ['G238', 'G47', 'G290', 'G242', 'G162', 'G130', 'G65', 'G11', 'G300', 'G139']
print('## ML로 뽑은 10개 유전자: ', test_genetic)

model1_train, model1_test = TestML(test_model1, test_genetic)
model2_train, model2_test = TestML(test_model2, test_genetic)


#draw table
model_train_results = np.array([[np.round(np.max(model1_train), 3), np.round(np.min(model1_train), 3)],
                               [np.round(np.max(model1_test), 3),np.round(np.min(model1_test), 3)],
                               [np.round(np.max(model2_train), 3),np.round(np.min(model2_train), 3)],
                               [np.round(np.max(model2_test), 3),np.round(np.min(model2_test), 3)]])

display(pd.DataFrame(model_train_results, columns=['Max', 'Min'],
                     index=['RandomForest Train', 'RandomForest Test','LightGBM Train','LightGBM Test']))
# Out:
# ## ML로 뽑은 10개 유전자:  ['G238', 'G47', 'G290', 'G242', 'G162', 'G130', 'G65', 'G11', 'G300', 'G139']
# ## Train 정확도:  100.0 100.0
# ## Test 정확도:  0.595 0.565
#
# ## Train 정확도:  89.25 89.25
# ## Test 정확도:  0.6 0.6
#                         Max      Min
# RandomForest Train  100.000  100.000
# RandomForest Test     0.595    0.565
# LightGBM Train       89.250   89.250
# LightGBM Test         0.600    0.600

# %%
test_genetic = ['G238', 'G191', 'G242', 'G200', 'G130', 'G166', 'G124', 'G57', 'G263', 'G146']
print('## ML로 뽑은 10개 유전자: ', test_genetic)

model1_train, model1_test = TestML(test_model1, test_genetic)
model2_train, model2_test = TestML(test_model2, test_genetic)


#draw table
model_train_results = np.array([[np.round(np.max(model1_train), 3), np.round(np.min(model1_train), 3)],
                               [np.round(np.max(model1_test), 3),np.round(np.min(model1_test), 3)],
                               [np.round(np.max(model2_train), 3),np.round(np.min(model2_train), 3)],
                               [np.round(np.max(model2_test), 3),np.round(np.min(model2_test), 3)]])

display(pd.DataFrame(model_train_results, columns=['Max', 'Min'],
                     index=['RandomForest Train', 'RandomForest Test','LightGBM Train','LightGBM Test']))
# Out:
# ## ML로 뽑은 10개 유전자:  ['G238', 'G191', 'G242', 'G200', 'G130', 'G166', 'G124', 'G57', 'G263', 'G146']
# ## Train 정확도:  100.0 100.0
# ## Test 정확도:  0.6 0.545
#
# ## Train 정확도:  89.375 89.375
# ## Test 정확도:  0.605 0.605
#                         Max      Min
# RandomForest Train  100.000  100.000
# RandomForest Test     0.600    0.545
# LightGBM Train       89.375   89.375
# LightGBM Test         0.605    0.605

# %%
test_genetic = ['G200', 'G18', 'G75', 'G6', 'G112', 'G148', 'G284', 'G9', 'G221', 'G187']
print('## ML로 뽑은 10개 유전자: ', test_genetic)

model1_train, model1_test = TestML(test_model1, test_genetic)
model2_train, model2_test = TestML(test_model2, test_genetic)

#draw table
model_train_results = np.array([[np.round(np.max(model1_train), 3), np.round(np.min(model1_train), 3)],
                               [np.round(np.max(model1_test), 3),np.round(np.min(model1_test), 3)],
                               [np.round(np.max(model2_train), 3),np.round(np.min(model2_train), 3)],
                               [np.round(np.max(model2_test), 3),np.round(np.min(model2_test), 3)]])

display(pd.DataFrame(model_train_results, columns=['Max', 'Min'],
                     index=['RandomForest Train', 'RandomForest Test','LightGBM Train','LightGBM Test']))
# Out:
# ## ML로 뽑은 10개 유전자:  ['G200', 'G18', 'G75', 'G6', 'G112', 'G148', 'G284', 'G9', 'G221', 'G187']
# ## Train 정확도:  100.0 100.0
# ## Test 정확도:  0.6 0.515
#
# ## Train 정확도:  89.875 89.875
# ## Test 정확도:  0.61 0.61
#                         Max      Min
# RandomForest Train  100.000  100.000
# RandomForest Test     0.600    0.515
# LightGBM Train       89.875   89.875
# LightGBM Test         0.610    0.610

# %%
# Out:
# outlier of time:
# 905   -7.945621
# Name: time, dtype: float64
#
#               time        event
# count  1000.000000  1000.000000
# mean     51.876125     0.891000
# std      22.122689     0.311795
# min       7.070708     0.000000
# 25%      37.401307     1.000000
# 50%      47.064712     1.000000
# 75%      60.966476     1.000000
# max     217.078908     1.000000

# %%
# Out:
# # Var1
# 2    235
# 3    204
# 1    171
# 4    139
# 5     95
# 0     57
# 6     50
# 7     27
# 8     13
# 9      9
# Name: Var1, dtype: int64
# --------------------
# # Var2
# 3    221
# 2    218
# 4    163
# 1    113
# 5    109
# 6     65
# 0     48
# 7     30
# 9     20
# 8     13
# Name: Var2, dtype: int64
# --------------------
# # Var3
# 2    260
# 3    196
# 1    156
# 4    130
# 5     97
# 0     55
# 6     55
# 7     23
# 8     16
# 9     12
# Name: Var3, dtype: int64
# --------------------
# # Var4
# 2    242
# 3    195
# 1    150
# 4    140
# 5    106
# 6     67
# 0     36
# 7     32
# 8     16
# 9     16
# Name: Var4, dtype: int64
# --------------------
# # Var5
# 2    247
# 3    223
# 4    161
# 5    124
# 1     76
# 6     63
# 7     41
# 0     28
# 9     19
# 8     18
# Name: Var5, dtype: int64
# --------------------
# # Var6
# 2    240
# 3    212
# 4    128
# 1    127
# 5     99
# 6     64
# 0     53
# 7     40
# 8     20
# 9     17
# Name: Var6, dtype: int64
# --------------------
# # Var7
# 1    269
# 2    208
# 3    144
# 0    128
# 4    118
# 5     62
# 6     47
# 7     16
# 8      6
# 9      2
# Name: Var7, dtype: int64
# --------------------
# # Var8
# 1    241
# 2    227
# 3    171
# 0    127
# 4    101
# 5     69
# 6     30
# 7     20
# 8     10
# 9      4
# Name: Var8, dtype: int64
# --------------------
# # Var9
# 2    250
# 1    235
# 3    157
# 0    135
# 4    100
# 5     57
# 6     33
# 7     22
# 9      6
# 8      5
# Name: Var9, dtype: int64
# --------------------
# # Var10
# 1    287
# 2    205
# 3    156
# 0    114
# 4    108
# 5     62
# 6     40
# 7     18
# 8      5
# 9      5
# Name: Var10, dtype: int64
# --------------------

# %%
# Out:
# # Var1
# 0.3    235
# 0.4    204
# 0.2    171
# 0.5    139
# 0.6     95
# 0.1     57
# 0.7     50
# 0.8     27
# 0.9     13
# 1.0      9
# Name: Var1, dtype: int64
# --------------------
# # Var2
# 0.4    221
# 0.3    218
# 0.5    163
# 0.2    113
# 0.6    109
# 0.7     65
# 0.1     48
# 0.8     30
# 1.0     20
# 0.9     13
# Name: Var2, dtype: int64
# --------------------
# # Var3
# 0.3    260
# 0.4    196
# 0.2    156
# 0.5    130
# 0.6     97
# 0.1     55
# 0.7     55
# 0.8     23
# 0.9     16
# 1.0     12
# Name: Var3, dtype: int64
# --------------------
# # Var4
# 0.3    242
# 0.4    195
# 0.2    150
# 0.5    140
# 0.6    106
# 0.7     67
# 0.1     36
# 0.8     32
# 0.9     16
# 1.0     16
# Name: Var4, dtype: int64
# --------------------
# # Var5
# 0.3    247
# 0.4    223
# 0.5    161
# 0.6    124
# 0.2     76
# 0.7     63
# 0.8     41
# 0.1     28
# 1.0     19
# 0.9     18
# Name: Var5, dtype: int64
# --------------------
# # Var6
# 0.3    240
# 0.4    212
# 0.5    128
# 0.2    127
# 0.6     99
# 0.7     64
# 0.1     53
# 0.8     40
# 0.9     20
# 1.0     17
# Name: Var6, dtype: int64
# --------------------
# # Var7
# 0.2    269
# 0.3    208
# 0.4    144
# 0.1    128
# 0.5    118
# 0.6     62
# 0.7     47
# 0.8     16
# 0.9      6
# 1.0      2
# Name: Var7, dtype: int64
# --------------------
# # Var8
# 0.2    241
# 0.3    227
# 0.4    171
# 0.1    127
# 0.5    101
# 0.6     69
# 0.7     30
# 0.8     20
# 0.9     10
# 1.0      4
# Name: Var8, dtype: int64
# --------------------
# # Var9
# 0.3    250
# 0.2    235
# 0.4    157
# 0.1    135
# 0.5    100
# 0.6     57
# 0.7     33
# 0.8     22
# 1.0      6
# 0.9      5
# Name: Var9, dtype: int64
# --------------------
# # Var10
# 0.2    287
# 0.3    205
# 0.4    156
# 0.1    114
# 0.5    108
# 0.6     62
# 0.7     40
# 0.8     18
# 0.9      5
# 1.0      5
# Name: Var10, dtype: int64
# --------------------

# %%
# Out:
#     G1   G2   G3   G4   G5   G6   G7   G8   G9  G10  ...  G291  G292  G293  \
# 0 -0.5  0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5  ...  -0.5  -0.5  -0.5
# 1 -0.5  0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5  ...  -0.5  -0.5  -0.5
# 2 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5  ...  -0.5  -0.5  -0.5
# 3 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5  0.5 -0.5  0.5  ...  -0.5   0.5  -0.5
# 4 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5  ...  -0.5  -0.5  -0.5
# 5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5  ...  -0.5  -0.5  -0.5
# 6 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5  ...  -0.5  -0.5  -0.5
# 7 -0.5 -0.5 -0.5  0.5 -0.5 -0.5 -0.5 -0.5 -0.5  0.5  ...  -0.5  -0.5  -0.5
# 8 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5  ...  -0.5  -0.5  -0.5
# 9 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5  ...  -0.5  -0.5  -0.5
#
#    G294  G295  G296  G297  G298  G299  G300
# 0  -0.5  -0.5  -0.5  -0.5  -0.5  -0.5  -0.5
# 1  -0.5  -0.5  -0.5  -0.5  -0.5  -0.5  -0.5
# 2  -0.5  -0.5  -0.5  -0.5  -0.5  -0.5  -0.5
# 3   0.5  -0.5  -0.5  -0.5  -0.5  -0.5  -0.5
# 4  -0.5  -0.5  -0.5  -0.5  -0.5  -0.5   0.5
# 5  -0.5  -0.5  -0.5  -0.5  -0.5  -0.5  -0.5
# 6  -0.5  -0.5   0.5  -0.5  -0.5  -0.5  -0.5
# 7  -0.5  -0.5   0.5   0.5  -0.5  -0.5  -0.5
# 8  -0.5  -0.5  -0.5  -0.5  -0.5  -0.5  -0.5
# 9  -0.5  -0.5  -0.5  -0.5  -0.5  -0.5  -0.5
#
# [10 rows x 300 columns]

# %%
# Out:
# ## test_model1 (Train accuracy가 100인 경우의 모델)
# ## Train 정확도:  100.0 100.0
# ## Test 정확도:  0.635 0.56
#
# ## test_model2 (Train accuracy가 100이 아닌 경우의 모델)
# ## Train 정확도:  94.25 94.25
# ## Test 정확도:  0.63 0.63

# %%
model_train_results = np.array([[np.round(np.max(model1_train), 3), np.round(np.min(model1_train), 3)],
                               [np.round(np.max(model1_test), 3),np.round(np.min(model1_test), 3)]])

display(pd.DataFrame(model_train_results, columns=['Max', 'Min'],
                     index=['RandomForest Train', 'RandomForest Test']))
# Out:
#                        Max      Min
# RandomForest Train  100.00  100.000
# RandomForest Test   0.65    0.565

# %%
print('## test_model2 (Train accuracy가 100이 아닌 경우의 모델)')
model2_train, model2_test = TestML(test_model2, selected_genetic)
# Out:
# ## test_model2 (Train accuracy가 100이 아닌 경우의 모델)
# ## Train 정확도:  89.25 89.25
# ## Test 정확도:  0.635 0.635

# %%
# Out:
#                         Max      Min
# RandomForest Train  100.000  100.000
# RandomForest Test   0.650    0.565
# LightGBM Train      89.250   89.250
# LightGBM Test       0.635    0.635

# %%
# Out:
# [100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0]
# [0.585, 0.565, 0.6, 0.57, 0.565, 0.59, 0.605, 0.58, 0.585, 0.605, 0.575, 0.575, 0.575, 0.6, 0.585, 0.595, 0.575, 0.615, 0.58, 0.65]
# [92.75, 92.75, 92.75, 92.75, 92.75, 92.75, 92.75, 92.75, 92.75, 92.75, 92.75, 92.75, 92.75, 92.75, 92.75, 92.75, 92.75, 92.75, 92.75, 92.75]
# [0.63, 0.63, 0.63, 0.63, 0.63, 0.63, 0.63, 0.63, 0.63, 0.63, 0.63, 0.63, 0.63, 0.63, 0.63, 0.63, 0.63, 0.63, 0.63, 0.63]

# %%
# '''
# 20번 돌린 것을 100번 돌린 경우

# '''
# selected_genetic = ['G211', 'G179', 'G80', 'G27', 'G147', 'G139', 'G242', 'G264', 'G290', 'G130']


# print('## test_model1 (Train accuracy가 100인 경우의 모델)')
# train_result, test_result = [], []
# for i in range(100):
#     tmp1, tmp2 = TestML(test_model1, selected_genetic)
#     train_result.extend(tmp1)
#     test_result.extend(tmp2)
    
# print('## Train 평균 정확도: ', np.round(np.mean(train_result), 3))
# print('## Test 평균 정확도: ', np.round(np.mean(test_result),3))
# print()

# print('## test_model2 (Train accuracy가 100이 아닌 경우의 모델)')
# train_result, test_result = [], []
# for i in range(100):
#     tmp1, tmp2 = TestML(test_model2, selected_genetic)
#     train_result.extend(tmp1)
#     test_result.extend(tmp2)
    
# print('## Train 평균 정확도: ', np.round(np.mean(train_result), 3))
# print('## Test 평균 정확도: ', np.round(np.mean(test_result),3))
# Out:
# ## test_model1 (Train accuracy가 100인 경우의 모델)
# ## Train 평균 정확도:  99.998
# ## Test 평균 정확도:  0.584
#
# ## test_model2 (Train accuracy가 100이 아닌 경우의 모델)
# ## Train 평균 정확도:  92.75
# ## Test 평균 정확도:  0.63

# %%
'''
20번 돌린 것을 100번 돌린 경우

'''
selected_genetic = ['G203', 'G195', 'G297', 'G208', 'G196', 'G115', 'G290', 'G235', 'G253', 'G240']


print('## test_model2 (Train accuracy가 100이 아닌 경우의 모델)')
train_result, test_result = [], []
for i in range(100):
    tmp1, tmp2 = TestML(test_model2, selected_genetic)
    train_result.extend(tmp1)
    test_result.extend(tmp2)
    
print('## Train 평균 정확도: ', np.round(np.mean(train_result), 3))
print('## Test 평균 정확도: ', np.round(np.mean(test_result),3))
# Out:
# ## test_model2 (Train accuracy가 100이 아닌 경우의 모델)
# ## Train 평균 정확도:  89.375
# ## Test 평균 정확도:  0.645

# %%
'''
20번 돌린 것을 100번 돌린 경우

'''
selected_genetic = ['G211', 'G179', 'G80', 'G27', 'G147', 'G139', 'G242', 'G264', 'G290', 'G130']


print('## test_model2 (Train accuracy가 100이 아닌 경우의 모델)')
train_result, test_result = [], []
for i in range(100):
    tmp1, tmp2 = TestML(test_model2, selected_genetic)
    train_result.extend(tmp1)
    test_result.extend(tmp2)
    
print('## Train 평균 정확도: ', np.round(np.mean(train_result), 3))
print('## Test 평균 정확도: ', np.round(np.mean(test_result),3))
# Out:
# ## test_model2 (Train accuracy가 100이 아닌 경우의 모델)
# ## Train 평균 정확도:  89.25
# ## Test 평균 정확도:  0.635

# %%
# Out:
# ## 임의의 10개 유전자:  ['G252', 'G195', 'G65', 'G253', 'G40', 'G255', 'G4', 'G59', 'G186', 'G140']
# ## Train 정확도:  89.375 89.375
# ## Test 정확도:  0.58 0.58
#
# ## 임의의 10개 유전자:  ['G45', 'G101', 'G166', 'G199', 'G52', 'G72', 'G250', 'G68', 'G255', 'G137']
# ## Train 정확도:  89.25 89.25
# ## Test 정확도:  0.625 0.625
#
# ## 임의의 10개 유전자:  ['G132', 'G98', 'G226', 'G286', 'G292', 'G134', 'G168', 'G257', 'G61', 'G190']
# ## Train 정확도:  88.75 88.75
# ## Test 정확도:  0.595 0.595
#
# ## 임의의 10개 유전자:  ['G115', 'G127', 'G257', 'G193', 'G179', 'G228', 'G141', 'G181', 'G217', 'G190']
# ## Train 정확도:  90.125 90.125
# ## Test 정확도:  0.61 0.61
#
# ## 임의의 10개 유전자:  ['G213', 'G179', 'G141', 'G31', 'G28', 'G168', 'G139', 'G237', 'G45', 'G3']
# ## Train 정확도:  89.0 89.0
# ## Test 정확도:  0.625 0.625
#
# ## 임의의 10개 유전자:  ['G237', 'G120', 'G77', 'G255', 'G32', 'G297', 'G129', 'G96', 'G126', 'G196']
# ## Train 정확도:  89.25 89.25
# ## Test 정확도:  0.6 0.6
#
# ## 임의의 10개 유전자:  ['G222', 'G104', 'G16', 'G270', 'G65', 'G198', 'G257', 'G126', 'G219', 'G296']
# ## Train 정확도:  88.625 88.625
# ## Test 정확도:  0.58 0.58
#
# ## 임의의 10개 유전자:  ['G245', 'G43', 'G180', 'G67', 'G17', 'G193', 'G293', 'G172', 'G218', 'G247']
# ## Train 정확도:  89.625 89.625
# ## Test 정확도:  0.605 0.605
#
# ## 임의의 10개 유전자:  ['G164', 'G1', 'G132', 'G68', 'G216', 'G214', 'G100', 'G204', 'G245', 'G114']
# ## Train 정확도:  90.125 90.125
# ## Test 정확도:  0.62 0.62
#
# ## 임의의 10개 유전자:  ['G143', 'G263', 'G107', 'G238', 'G106', 'G296', 'G68', 'G43', 'G129', 'G135']
# ## Train 정확도:  90.125 90.125
# ## Test 정확도:  0.605 0.605
#
# ## 임의의 10개 유전자:  ['G36', 'G114', 'G38', 'G123', 'G129', 'G168', 'G232', 'G298', 'G300', 'G17']
# ## Train 정확도:  90.0 90.0
# ## Test 정확도:  0.61 0.61
#
# ## 임의의 10개 유전자:  ['G3', 'G115', 'G97', 'G210', 'G106', 'G241', 'G98', 'G179', 'G258', 'G216']
# ## Train 정확도:  89.5 89.5
# ## Test 정확도:  0.62 0.62
#
# ## 임의의 10개 유전자:  ['G37', 'G70', 'G49', 'G228', 'G266', 'G86', 'G284', 'G134', 'G131', 'G245']
# ## Train 정확도:  88.875 88.875
# ## Test 정확도:  0.62 0.62
#
# ## 임의의 10개 유전자:  ['G253', 'G241', 'G168', 'G36', 'G98', 'G153', 'G296', 'G7', 'G78', 'G134']
# ## Train 정확도:  88.5 88.5
# ## Test 정확도:  0.6 0.6
#
# ## 임의의 10개 유전자:  ['G195', 'G117', 'G100', 'G148', 'G271', 'G273', 'G290', 'G95', 'G142', 'G131']
# ## Train 정확도:  88.5 88.5
# ## Test 정확도:  0.605 0.605
#
# ## 임의의 10개 유전자:  ['G110', 'G219', 'G220', 'G157', 'G176', 'G12', 'G72', 'G290', 'G125', 'G60']
# ## Train 정확도:  89.0 89.0
# ## Test 정확도:  0.63 0.63
#
# ## 임의의 10개 유전자:  ['G63', 'G44', 'G97', 'G267', 'G189', 'G9', 'G161', 'G273', 'G70', 'G46']
# ## Train 정확도:  90.25 90.25
# ## Test 정확도:  0.62 0.62
#
# ## 임의의 10개 유전자:  ['G286', 'G7', 'G288', 'G252', 'G282', 'G261', 'G134', 'G247', 'G190', 'G164']
# ## Train 정확도:  87.875 87.875
# ## Test 정확도:  0.61 0.61
#
# ## 임의의 10개 유전자:  ['G186', 'G268', 'G292', 'G271', 'G121', 'G233', 'G245', 'G229', 'G9', 'G88']
# ## Train 정확도:  89.75 89.75
# ## Test 정확도:  0.615 0.615
#
# ## 임의의 10개 유전자:  ['G66', 'G300', 'G178', 'G99', 'G156', 'G144', 'G42', 'G167', 'G225', 'G277']
# ## Train 정확도:  89.0 89.0
# ## Test 정확도:  0.595 0.595
#
# ## 임의의 10개 유전자:  ['G208', 'G270', 'G279', 'G260', 'G77', 'G136', 'G19', 'G31', 'G227', 'G9']
# ## Train 정확도:  90.0 90.0
# ## Test 정확도:  0.605 0.605
#
# ## 임의의 10개 유전자:  ['G24', 'G90', 'G219', 'G208', 'G105', 'G106', 'G38', 'G193', 'G21', 'G117']
# ## Train 정확도:  89.75 89.75
# ## Test 정확도:  0.62 0.62
#
# ## 임의의 10개 유전자:  ['G217', 'G292', 'G178', 'G158', 'G109', 'G2', 'G143', 'G246', 'G150', 'G87']
# ## Train 정확도:  89.875 89.875
# ## Test 정확도:  0.605 0.605
#
# ## 임의의 10개 유전자:  ['G225', 'G155', 'G146', 'G96', 'G285', 'G184', 'G21', 'G38', 'G152', 'G216']
# ## Train 정확도:  90.125 90.125
# ## Test 정확도:  0.63 0.63
#
# ## 임의의 10개 유전자:  ['G9', 'G101', 'G173', 'G261', 'G144', 'G220', 'G121', 'G35', 'G253', 'G103']
# ## Train 정확도:  89.375 89.375
# ## Test 정확도:  0.645 0.645
#
# -----------------Over!-----------------
#
#
# ## 임의의 10개 유전자:  ['G37', 'G19', 'G11', 'G266', 'G255', 'G261', 'G22', 'G249', 'G15', 'G213']
# ## Train 정확도:  89.5 89.5
# ## Test 정확도:  0.62 0.62
#
# ## 임의의 10개 유전자:  ['G213', 'G61', 'G279', 'G142', 'G170', 'G199', 'G200', 'G295', 'G122', 'G41']
# ## Train 정확도:  89.625 89.625
# ## Test 정확도:  0.615 0.615
#
# ## 임의의 10개 유전자:  ['G66', 'G211', 'G248', 'G198', 'G71', 'G270', 'G219', 'G158', 'G50', 'G72']
# ## Train 정확도:  88.625 88.625
# ## Test 정확도:  0.61 0.61
#
# ## 임의의 10개 유전자:  ['G12', 'G213', 'G209', 'G289', 'G35', 'G218', 'G192', 'G242', 'G163', 'G99']
# ## Train 정확도:  88.25 88.25
# ## Test 정확도:  0.625 0.625
#
# ## 임의의 10개 유전자:  ['G130', 'G220', 'G232', 'G168', 'G144', 'G108', 'G19', 'G95', 'G83', 'G178']
# ## Train 정확도:  88.5 88.5
# ## Test 정확도:  0.61 0.61
#
# ## 임의의 10개 유전자:  ['G56', 'G147', 'G18', 'G118', 'G176', 'G39', 'G258', 'G227', 'G202', 'G9']
# ## Train 정확도:  88.875 88.875
# ## Test 정확도:  0.625 0.625
#
# ## 임의의 10개 유전자:  ['G275', 'G71', 'G93', 'G284', 'G291', 'G96', 'G209', 'G132', 'G1', 'G78']
# ## Train 정확도:  90.375 90.375
# ## Test 정확도:  0.64 0.64
#
# -----------------Over!-----------------
#
#
# ## 임의의 10개 유전자:  ['G137', 'G211', 'G175', 'G68', 'G94', 'G7', 'G166', 'G204', 'G140', 'G241']
# ## Train 정확도:  89.75 89.75
# ## Test 정확도:  0.605 0.605
#
# ## 임의의 10개 유전자:  ['G145', 'G114', 'G49', 'G169', 'G252', 'G171', 'G248', 'G131', 'G63', 'G241']
# ## Train 정확도:  90.125 90.125
# ## Test 정확도:  0.585 0.585
#
# ## 임의의 10개 유전자:  ['G290', 'G109', 'G182', 'G185', 'G85', 'G221', 'G147', 'G66', 'G130', 'G237']
# ## Train 정확도:  88.625 88.625
# ## Test 정확도:  0.59 0.59
#
# ## 임의의 10개 유전자:  ['G201', 'G230', 'G288', 'G60', 'G158', 'G198', 'G142', 'G160', 'G84', 'G94']
# ## Train 정확도:  89.875 89.875
# ## Test 정확도:  0.59 0.59
#
# ## 임의의 10개 유전자:  ['G116', 'G88', 'G156', 'G113', 'G45', 'G198', 'G125', 'G14', 'G131', 'G197']
# ## Train 정확도:  88.75 88.75
# ## Test 정확도:  0.6 0.6
#
# ## 임의의 10개 유전자:  ['G172', 'G47', 'G185', 'G168', 'G181', 'G86', 'G154', 'G274', 'G96', 'G272']
# ## Train 정확도:  88.875 88.875
# ## Test 정확도:  0.61 0.61
#
# ## 임의의 10개 유전자:  ['G125', 'G213', 'G81', 'G157', 'G8', 'G242', 'G298', 'G117', 'G19', 'G104']
# ## Train 정확도:  89.875 89.875
# ## Test 정확도:  0.605 0.605
#
# ## 임의의 10개 유전자:  ['G83', 'G254', 'G288', 'G42', 'G99', 'G124', 'G279', 'G13', 'G41', 'G267']
# ## Train 정확도:  87.875 87.875
# ## Test 정확도:  0.61 0.61
#
# ## 임의의 10개 유전자:  ['G100', 'G106', 'G8', 'G51', 'G139', 'G26', 'G217', 'G266', 'G191', 'G88']
# ## Train 정확도:  89.875 89.875
# ## Test 정확도:  0.61 0.61
#
# ## 임의의 10개 유전자:  ['G92', 'G106', 'G198', 'G107', 'G65', 'G153', 'G120', 'G140', 'G60', 'G154']
# ## Train 정확도:  88.875 88.875
# ## Test 정확도:  0.615 0.615
#
# ## 임의의 10개 유전자:  ['G265', 'G299', 'G124', 'G123', 'G200', 'G275', 'G224', 'G261', 'G300', 'G239']
# ## Train 정확도:  91.25 91.25
# ## Test 정확도:  0.595 0.595
#
# ## 임의의 10개 유전자:  ['G138', 'G115', 'G73', 'G57', 'G256', 'G83', 'G17', 'G48', 'G297', 'G300']
# ## Train 정확도:  89.75 89.75
# ## Test 정확도:  0.63 0.63
#
# ## 임의의 10개 유전자:  ['G155', 'G160', 'G205', 'G112', 'G148', 'G109', 'G195', 'G70', 'G45', 'G218']
# ## Train 정확도:  89.0 89.0
# ## Test 정확도:  0.625 0.625
#
# ## 임의의 10개 유전자:  ['G269', 'G170', 'G33', 'G8', 'G117', 'G93', 'G40', 'G105', 'G143', 'G83']
# ## Train 정확도:  89.25 89.25
# ## Test 정확도:  0.635 0.635
#
# -----------------Over!-----------------
#
#
# ## 임의의 10개 유전자:  ['G275', 'G82', 'G169', 'G226', 'G173', 'G29', 'G56', 'G172', 'G164', 'G10']
# ## Train 정확도:  88.75 88.75
# ## Test 정확도:  0.6 0.6
#
# ## 임의의 10개 유전자:  ['G179', 'G273', 'G221', 'G226', 'G41', 'G25', 'G176', 'G164', 'G84', 'G117']
# ## Train 정확도:  89.375 89.375
# ## Test 정확도:  0.63 0.63
#
# ## 임의의 10개 유전자:  ['G285', 'G230', 'G70', 'G273', 'G156', 'G254', 'G270', 'G117', 'G69', 'G277']
# ## Train 정확도:  88.375 88.375
# ## Test 정확도:  0.595 0.595
#
# ## 임의의 10개 유전자:  ['G235', 'G183', 'G148', 'G166', 'G170', 'G130', 'G190', 'G39', 'G186', 'G26']
# ## Train 정확도:  88.5 88.5
# ## Test 정확도:  0.61 0.61
#
# ## 임의의 10개 유전자:  ['G26', 'G123', 'G152', 'G264', 'G287', 'G27', 'G4', 'G225', 'G80', 'G43']
# ## Train 정확도:  90.125 90.125
# ## Test 정확도:  0.605 0.605
#
# ## 임의의 10개 유전자:  ['G188', 'G168', 'G262', 'G22', 'G82', 'G87', 'G72', 'G80', 'G209', 'G19']
# ## Train 정확도:  89.625 89.625
# ## Test 정확도:  0.625 0.625
#
# ## 임의의 10개 유전자:  ['G235', 'G58', 'G216', 'G228', 'G211', 'G283', 'G5', 'G243', 'G162', 'G278']
# ## Train 정확도:  89.125 89.125
# ## Test 정확도:  0.595 0.595
#
# ## 임의의 10개 유전자:  ['G122', 'G138', 'G133', 'G165', 'G74', 'G115', 'G90', 'G31', 'G222', 'G70']
# ## Train 정확도:  89.625 89.625
# ## Test 정확도:  0.62 0.62
#
# ## 임의의 10개 유전자:  ['G206', 'G216', 'G199', 'G110', 'G228', 'G299', 'G85', 'G8', 'G268', 'G167']
# ## Train 정확도:  89.125 89.125
# ## Test 정확도:  0.62 0.62
#
# ## 임의의 10개 유전자:  ['G54', 'G279', 'G191', 'G283', 'G128', 'G262', 'G140', 'G238', 'G163', 'G52']
# ## Train 정확도:  90.0 90.0
# ## Test 정확도:  0.615 0.615
#
# ## 임의의 10개 유전자:  ['G274', 'G160', 'G217', 'G220', 'G135', 'G278', 'G21', 'G166', 'G45', 'G130']
# ## Train 정확도:  88.25 88.25
# ## Test 정확도:  0.605 0.605
#
# ## 임의의 10개 유전자:  ['G158', 'G219', 'G194', 'G134', 'G139', 'G64', 'G286', 'G42', 'G100', 'G98']
# ## Train 정확도:  89.0 89.0
# ## Test 정확도:  0.61 0.61
#
# ## 임의의 10개 유전자:  ['G20', 'G137', 'G288', 'G217', 'G231', 'G226', 'G85', 'G274', 'G9', 'G13']
# ## Train 정확도:  89.125 89.125
# ## Test 정확도:  0.62 0.62
#
# ## 임의의 10개 유전자:  ['G275', 'G78', 'G21', 'G114', 'G63', 'G100', 'G10', 'G84', 'G238', 'G269']
# ## Train 정확도:  89.25 89.25
# ## Test 정확도:  0.615 0.615
#
# ## 임의의 10개 유전자:  ['G129', 'G240', 'G135', 'G68', 'G229', 'G74', 'G300', 'G163', 'G151', 'G104']
# ## Train 정확도:  89.125 89.125
# ## Test 정확도:  0.595 0.595
#
# ## 임의의 10개 유전자:  ['G283', 'G152', 'G120', 'G10', 'G79', 'G19', 'G255', 'G266', 'G135', 'G146']
# ## Train 정확도:  88.875 88.875
# ## Test 정확도:  0.63 0.63
#
# ## 임의의 10개 유전자:  ['G298', 'G145', 'G102', 'G130', 'G56', 'G252', 'G91', 'G60', 'G165', 'G6']
# ## Train 정확도:  89.875 89.875
# ## Test 정확도:  0.605 0.605
#
# ## 임의의 10개 유전자:  ['G82', 'G299', 'G240', 'G39', 'G124', 'G118', 'G253', 'G88', 'G149', 'G228']
# ## Train 정확도:  89.75 89.75
# ## Test 정확도:  0.615 0.615
#
# ## 임의의 10개 유전자:  ['G143', 'G163', 'G216', 'G134', 'G197', 'G41', 'G196', 'G29', 'G11', 'G138']
# ## Train 정확도:  89.0 89.0
# ## Test 정확도:  0.595 0.595
#
# ## 임의의 10개 유전자:  ['G231', 'G61', 'G225', 'G295', 'G246', 'G163', 'G73', 'G282', 'G177', 'G45']
# ## Train 정확도:  90.125 90.125
# ## Test 정확도:  0.61 0.61
#
# ## 임의의 10개 유전자:  ['G100', 'G37', 'G144', 'G115', 'G257', 'G298', 'G252', 'G248', 'G27', 'G122']
# ## Train 정확도:  88.625 88.625
# ## Test 정확도:  0.585 0.585
#
# ## 임의의 10개 유전자:  ['G194', 'G82', 'G278', 'G76', 'G216', 'G139', 'G158', 'G13', 'G81', 'G300']
# ## Train 정확도:  90.375 90.375
# ## Test 정확도:  0.615 0.615
#
# ## 임의의 10개 유전자:  ['G13', 'G123', 'G199', 'G271', 'G201', 'G281', 'G221', 'G275', 'G19', 'G242']
# ## Train 정확도:  89.375 89.375
# ## Test 정확도:  0.615 0.615
#
# ## 임의의 10개 유전자:  ['G294', 'G162', 'G158', 'G16', 'G7', 'G72', 'G73', 'G27', 'G250', 'G138']
# ## Train 정확도:  89.5 89.5
# ## Test 정확도:  0.595 0.595
#
# ## 임의의 10개 유전자:  ['G198', 'G42', 'G117', 'G248', 'G237', 'G34', 'G287', 'G32', 'G147', 'G191']
# ## Train 정확도:  89.625 89.625
# ## Test 정확도:  0.615 0.615
#
# ## 임의의 10개 유전자:  ['G32', 'G23', 'G223', 'G9', 'G56', 'G8', 'G142', 'G242', 'G195', 'G53']
# ## Train 정확도:  88.875 88.875
# ## Test 정확도:  0.61 0.61
#
# ## 임의의 10개 유전자:  ['G36', 'G176', 'G259', 'G124', 'G107', 'G135', 'G11', 'G254', 'G103', 'G1']
# ## Train 정확도:  90.375 90.375
# ## Test 정확도:  0.59 0.59
#
# ## 임의의 10개 유전자:  ['G113', 'G38', 'G128', 'G84', 'G31', 'G249', 'G171', 'G23', 'G65', 'G163']
# ## Train 정확도:  89.125 89.125
# ## Test 정확도:  0.605 0.605
#
# ## 임의의 10개 유전자:  ['G61', 'G79', 'G155', 'G110', 'G281', 'G62', 'G194', 'G225', 'G239', 'G162']
# ## Train 정확도:  89.25 89.25
# ## Test 정확도:  0.64 0.64
#
# -----------------Over!-----------------
#
#
# ## 임의의 10개 유전자:  ['G226', 'G42', 'G23', 'G2', 'G273', 'G138', 'G285', 'G155', 'G218', 'G48']
# ## Train 정확도:  89.5 89.5
# ## Test 정확도:  0.63 0.63
#
# ## 임의의 10개 유전자:  ['G242', 'G120', 'G145', 'G129', 'G140', 'G130', 'G67', 'G88', 'G49', 'G11']
# ## Train 정확도:  89.625 89.625
# ## Test 정확도:  0.61 0.61
#
# ## 임의의 10개 유전자:  ['G138', 'G290', 'G218', 'G264', 'G275', 'G211', 'G14', 'G93', 'G235', 'G245']
# ## Train 정확도:  89.875 89.875
# ## Test 정확도:  0.625 0.625
#
# ## 임의의 10개 유전자:  ['G103', 'G124', 'G144', 'G16', 'G87', 'G18', 'G242', 'G221', 'G282', 'G140']
# ## Train 정확도:  90.0 90.0
# ## Test 정확도:  0.58 0.58
#
# ## 임의의 10개 유전자:  ['G55', 'G286', 'G221', 'G258', 'G20', 'G86', 'G68', 'G194', 'G131', 'G128']
# ## Train 정확도:  88.875 88.875
# ## Test 정확도:  0.6 0.6
#
# ## 임의의 10개 유전자:  ['G103', 'G268', 'G184', 'G181', 'G72', 'G207', 'G17', 'G69', 'G244', 'G234']
# ## Train 정확도:  89.0 89.0
# ## Test 정확도:  0.605 0.605
#
# ## 임의의 10개 유전자:  ['G267', 'G103', 'G176', 'G131', 'G179', 'G160', 'G224', 'G180', 'G40', 'G17']
# ## Train 정확도:  89.5 89.5
# ## Test 정확도:  0.63 0.63
#
# ## 임의의 10개 유전자:  ['G184', 'G165', 'G277', 'G56', 'G240', 'G126', 'G238', 'G163', 'G48', 'G189']
# ## Train 정확도:  90.0 90.0
# ## Test 정확도:  0.615 0.615
#
# ## 임의의 10개 유전자:  ['G80', 'G54', 'G58', 'G47', 'G117', 'G292', 'G85', 'G63', 'G145', 'G14']
# ## Train 정확도:  90.375 90.375
# ## Test 정확도:  0.605 0.605
#
# ## 임의의 10개 유전자:  ['G145', 'G196', 'G189', 'G148', 'G52', 'G174', 'G22', 'G62', 'G207', 'G70']
# ## Train 정확도:  89.75 89.75
# ## Test 정확도:  0.6 0.6
#
# ## 임의의 10개 유전자:  ['G270', 'G239', 'G235', 'G44', 'G261', 'G51', 'G61', 'G230', 'G262', 'G279']
# ## Train 정확도:  89.25 89.25
# ## Test 정확도:  0.625 0.625
#
# ## 임의의 10개 유전자:  ['G109', 'G97', 'G245', 'G206', 'G88', 'G140', 'G41', 'G300', 'G278', 'G165']
# ## Train 정확도:  89.5 89.5
# ## Test 정확도:  0.6 0.6
#
# ## 임의의 10개 유전자:  ['G99', 'G91', 'G267', 'G147', 'G232', 'G29', 'G98', 'G186', 'G34', 'G200']
# ## Train 정확도:  89.625 89.625
# ## Test 정확도:  0.61 0.61
#
# ## 임의의 10개 유전자:  ['G116', 'G154', 'G55', 'G283', 'G76', 'G278', 'G227', 'G102', 'G199', 'G142']
# ## Train 정확도:  88.75 88.75
# ## Test 정확도:  0.62 0.62
#
# ## 임의의 10개 유전자:  ['G213', 'G78', 'G31', 'G219', 'G138', 'G93', 'G261', 'G279', 'G267', 'G227']
# ## Train 정확도:  90.25 90.25
# ## Test 정확도:  0.62 0.62
#
# ## 임의의 10개 유전자:  ['G21', 'G100', 'G49', 'G76', 'G157', 'G66', 'G146', 'G104', 'G244', 'G197']
# ## Train 정확도:  89.375 89.375
# ## Test 정확도:  0.625 0.625
#
# ## 임의의 10개 유전자:  ['G113', 'G60', 'G6', 'G31', 'G176', 'G37', 'G20', 'G215', 'G178', 'G224']
# ## Train 정확도:  90.5 90.5
# ## Test 정확도:  0.58 0.58
#
# ## 임의의 10개 유전자:  ['G59', 'G83', 'G294', 'G175', 'G105', 'G292', 'G150', 'G191', 'G81', 'G190']
# ## Train 정확도:  90.0 90.0
# ## Test 정확도:  0.58 0.58
#
# ## 임의의 10개 유전자:  ['G28', 'G8', 'G131', 'G45', 'G206', 'G227', 'G17', 'G144', 'G30', 'G78']
# ## Train 정확도:  88.625 88.625
# ## Test 정확도:  0.61 0.61
#
# ## 임의의 10개 유전자:  ['G68', 'G140', 'G70', 'G114', 'G83', 'G130', 'G104', 'G142', 'G167', 'G91']
# ## Train 정확도:  89.0 89.0
# ## Test 정확도:  0.62 0.62
#
# ## 임의의 10개 유전자:  ['G186', 'G273', 'G112', 'G43', 'G215', 'G289', 'G220', 'G100', 'G236', 'G252']
# ## Train 정확도:  88.875 88.875
# ## Test 정확도:  0.615 0.615
#
# ## 임의의 10개 유전자:  ['G186', 'G194', 'G127', 'G97', 'G59', 'G113', 'G212', 'G224', 'G76', 'G269']
# ## Train 정확도:  90.375 90.375
# ## Test 정확도:  0.62 0.62
#
# ## 임의의 10개 유전자:  ['G199', 'G90', 'G79', 'G290', 'G178', 'G22', 'G243', 'G117', 'G234', 'G38']
# ## Train 정확도:  88.125 88.125
# ## Test 정확도:  0.61 0.61
#
# ## 임의의 10개 유전자:  ['G21', 'G148', 'G69', 'G277', 'G63', 'G38', 'G118', 'G212', 'G214', 'G144']
# ## Train 정확도:  89.5 89.5
# ## Test 정확도:  0.61 0.61
#
# ## 임의의 10개 유전자:  ['G171', 'G141', 'G275', 'G37', 'G106', 'G116', 'G121', 'G268', 'G21', 'G142']
# ## Train 정확도:  89.75 89.75
# ## Test 정확도:  0.62 0.62
#
# ## 임의의 10개 유전자:  ['G60', 'G121', 'G177', 'G162', 'G218', 'G219', 'G92', 'G64', 'G281', 'G156']
# ## Train 정확도:  90.125 90.125
# ## Test 정확도:  0.615 0.615
#
# ## 임의의 10개 유전자:  ['G293', 'G241', 'G288', 'G86', 'G140', 'G107', 'G77', 'G55', 'G88', 'G141']
# ## Train 정확도:  89.125 89.125
# ## Test 정확도:  0.6 0.6
#
# ## 임의의 10개 유전자:  ['G49', 'G261', 'G279', 'G28', 'G33', 'G10', 'G168', 'G178', 'G55', 'G164']
# ## Train 정확도:  89.0 89.0
# ## Test 정확도:  0.605 0.605
#
# ## 임의의 10개 유전자:  ['G79', 'G229', 'G225', 'G84', 'G251', 'G255', 'G190', 'G226', 'G58', 'G80']
# ## Train 정확도:  89.5 89.5
# ## Test 정확도:  0.615 0.615
#
# ## 임의의 10개 유전자:  ['G139', 'G251', 'G279', 'G259', 'G125', 'G44', 'G3', 'G281', 'G225', 'G148']
# ## Train 정확도:  90.25 90.25
# ## Test 정확도:  0.63 0.63
#
# ## 임의의 10개 유전자:  ['G88', 'G52', 'G98', 'G193', 'G279', 'G211', 'G115', 'G264', 'G257', 'G53']
# ## Train 정확도:  89.875 89.875
# ## Test 정확도:  0.62 0.62
#
# ## 임의의 10개 유전자:  ['G18', 'G90', 'G54', 'G268', 'G226', 'G93', 'G95', 'G205', 'G248', 'G66']
# ## Train 정확도:  89.375 89.375
# ## Test 정확도:  0.6 0.6
#
# ## 임의의 10개 유전자:  ['G298', 'G299', 'G151', 'G57', 'G89', 'G128', 'G168', 'G206', 'G203', 'G274']
# ## Train 정확도:  89.5 89.5
# ## Test 정확도:  0.6 0.6
#
# ## 임의의 10개 유전자:  ['G127', 'G276', 'G159', 'G184', 'G227', 'G157', 'G203', 'G166', 'G11', 'G126']
# ## Train 정확도:  89.125 89.125
# ## Test 정확도:  0.61 0.61
#
# ## 임의의 10개 유전자:  ['G285', 'G23', 'G117', 'G213', 'G190', 'G57', 'G149', 'G71', 'G140', 'G292']
# ## Train 정확도:  89.75 89.75
# ## Test 정확도:  0.615 0.615

# %%
print(random_genetic_list[:-60])
# Out:
# ['G252', 'G195', 'G65', 'G253', 'G40', 'G255', 'G4', 'G59', 'G186', 'G140', 'G45', 'G101', 'G166', 'G199', 'G52', 'G72', 'G250', 'G68', 'G255', 'G137', 'G132', 'G98', 'G226', 'G286', 'G292', 'G134', 'G168', 'G257', 'G61', 'G190', 'G115', 'G127', 'G257', 'G193', 'G179', 'G228', 'G141', 'G181', 'G217', 'G190', 'G213', 'G179', 'G141', 'G31', 'G28', 'G168', 'G139', 'G237', 'G45', 'G3', 'G237', 'G120', 'G77', 'G255', 'G32', 'G297', 'G129', 'G96', 'G126', 'G196', 'G222', 'G104', 'G16', 'G270', 'G65', 'G198', 'G257', 'G126', 'G219', 'G296', 'G245', 'G43', 'G180', 'G67', 'G17', 'G193', 'G293', 'G172', 'G218', 'G247', 'G164', 'G1', 'G132', 'G68', 'G216', 'G214', 'G100', 'G204', 'G245', 'G114', 'G143', 'G263', 'G107', 'G238', 'G106', 'G296', 'G68', 'G43', 'G129', 'G135', 'G36', 'G114', 'G38', 'G123', 'G129', 'G168', 'G232', 'G298', 'G300', 'G17', 'G3', 'G115', 'G97', 'G210', 'G106', 'G241', 'G98', 'G179', 'G258', 'G216', 'G37', 'G70', 'G49', 'G228', 'G266', 'G86', 'G284', 'G134', 'G131', 'G245', 'G253', 'G241', 'G168', 'G36', 'G98', 'G153', 'G296', 'G7', 'G78', 'G134', 'G195', 'G117', 'G100', 'G148', 'G271', 'G273', 'G290', 'G95', 'G142', 'G131', 'G110', 'G219', 'G220', 'G157', 'G176', 'G12', 'G72', 'G290', 'G125', 'G60', 'G63', 'G44', 'G97', 'G267', 'G189', 'G9', 'G161', 'G273', 'G70', 'G46', 'G286', 'G7', 'G288', 'G252', 'G282', 'G261', 'G134', 'G247', 'G190', 'G164', 'G186', 'G268', 'G292', 'G271', 'G121', 'G233', 'G245', 'G229', 'G9', 'G88', 'G66', 'G300', 'G178', 'G99', 'G156', 'G144', 'G42', 'G167', 'G225', 'G277', 'G208', 'G270', 'G279', 'G260', 'G77', 'G136', 'G19', 'G31', 'G227', 'G9', 'G24', 'G90', 'G219', 'G208', 'G105', 'G106', 'G38', 'G193', 'G21', 'G117', 'G217', 'G292', 'G178', 'G158', 'G109', 'G2', 'G143', 'G246', 'G150', 'G87', 'G225', 'G155', 'G146', 'G96', 'G285', 'G184', 'G21', 'G38', 'G152', 'G216', 'G37', 'G19', 'G11', 'G266', 'G255', 'G261', 'G22', 'G249', 'G15', 'G213', 'G213', 'G61', 'G279', 'G142', 'G170', 'G199', 'G200', 'G295', 'G122', 'G41', 'G66', 'G211', 'G248', 'G198', 'G71', 'G270', 'G219', 'G158', 'G50', 'G72', 'G12', 'G213', 'G209', 'G289', 'G35', 'G218', 'G192', 'G242', 'G163', 'G99', 'G130', 'G220', 'G232', 'G168', 'G144', 'G108', 'G19', 'G95', 'G83', 'G178', 'G56', 'G147', 'G18', 'G118', 'G176', 'G39', 'G258', 'G227', 'G202', 'G9', 'G137', 'G211', 'G175', 'G68', 'G94', 'G7', 'G166', 'G204', 'G140', 'G241', 'G145', 'G114', 'G49', 'G169', 'G252', 'G171', 'G248', 'G131', 'G63', 'G241', 'G290', 'G109', 'G182', 'G185', 'G85', 'G221', 'G147', 'G66', 'G130', 'G237', 'G201', 'G230', 'G288', 'G60', 'G158', 'G198', 'G142', 'G160', 'G84', 'G94', 'G116', 'G88', 'G156', 'G113', 'G45', 'G198', 'G125', 'G14', 'G131', 'G197', 'G172', 'G47', 'G185', 'G168', 'G181', 'G86', 'G154', 'G274', 'G96', 'G272', 'G125', 'G213', 'G81', 'G157', 'G8', 'G242', 'G298', 'G117', 'G19', 'G104', 'G83', 'G254', 'G288', 'G42', 'G99', 'G124', 'G279', 'G13', 'G41', 'G267', 'G100', 'G106', 'G8', 'G51', 'G139', 'G26', 'G217', 'G266', 'G191', 'G88', 'G92', 'G106', 'G198', 'G107', 'G65', 'G153', 'G120', 'G140', 'G60', 'G154', 'G265', 'G299', 'G124', 'G123', 'G200', 'G275', 'G224', 'G261', 'G300', 'G239', 'G138', 'G115', 'G73', 'G57', 'G256', 'G83', 'G17', 'G48', 'G297', 'G300', 'G155', 'G160', 'G205', 'G112', 'G148', 'G109', 'G195', 'G70', 'G45', 'G218', 'G275', 'G82', 'G169', 'G226', 'G173', 'G29', 'G56', 'G172', 'G164', 'G10', 'G179', 'G273', 'G221', 'G226', 'G41', 'G25', 'G176', 'G164', 'G84', 'G117', 'G285', 'G230', 'G70', 'G273', 'G156', 'G254', 'G270', 'G117', 'G69', 'G277', 'G235', 'G183', 'G148', 'G166', 'G170', 'G130', 'G190', 'G39', 'G186', 'G26', 'G26', 'G123', 'G152', 'G264', 'G287', 'G27', 'G4', 'G225', 'G80', 'G43', 'G188', 'G168', 'G262', 'G22', 'G82', 'G87', 'G72', 'G80', 'G209', 'G19', 'G235', 'G58', 'G216', 'G228', 'G211', 'G283', 'G5', 'G243', 'G162', 'G278', 'G122', 'G138', 'G133', 'G165', 'G74', 'G115', 'G90', 'G31', 'G222', 'G70', 'G206', 'G216', 'G199', 'G110', 'G228', 'G299', 'G85', 'G8', 'G268', 'G167', 'G54', 'G279', ...

# %%
print(len(random_genetic_list))
# Out:
# 1000

# %%
random_genetic_list = random_genetic_list[:-60]

# %%
over_genetic_results = np.array(over_genetic)
pd.set_option('display.max_colwidth', -1)
display(pd.DataFrame(over_genetic_results, columns=['RandomSet', 'Result']))
# Out:
# <ipython-input-64-a8c716e20b7c>:2: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\anaconda3\lib\site-packages\pandas\core\internals\managers.py in create_block_manager_from_blocks(blocks, axes)
#    1674                 blocks = [
# -> 1675                     make_block(
#    1676                         values=blocks[0], placement=slice(0, len(axes[0])), ndim=2
#
# C:\anaconda3\lib\site-packages\pandas\core\internals\blocks.py in make_block(values, placement, klass, ndim, dtype)
#    2741
# -> 2742     return klass(values, ndim=ndim, placement=placement)
#    2743
#
# C:\anaconda3\lib\site-packages\pandas\core\internals\blocks.py in __init__(self, values, placement, ndim)
#     141         if self._validate_ndim and self.ndim and len(self.mgr_locs) != len(self.values):
# --> 142             raise ValueError(
#     143                 f"Wrong number of items passed {len(self.values)}, "
#
# ValueError: Wrong number of items passed 1, placement implies 2
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-64-a8c716e20b7c> in <module>
#       1 over_genetic_results = np.array(over_genetic)
#       2 pd.set_option('display.max_colwidth', -1)
# ----> 3 display(pd.DataFrame(over_genetic_results, columns=['RandomSet', 'Result']))
#
# C:\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     556                 mgr = init_dict({data.name: data}, index, columns, dtype=dtype)
#     557             else:
# --> 558                 mgr = init_ndarray(data, index, columns, dtype=dtype, copy=copy)
#     559
#     560         # For data is list-like, or Iterable (will consume into list)
#
# C:\anaconda3\lib\site-packages\pandas\core\internals\construction.py in init_ndarray(values, index, columns, dtype, copy)
#     236         block_values = [values]
#     237
# --> 238     return create_block_manager_from_blocks(block_values, [columns, index])
#     239
#     240
#
# C:\anaconda3\lib\site-packages\pandas\core\internals\managers.py in create_block_manager_from_blocks(blocks, axes)
#    1685         blocks = [getattr(b, "values", b) for b in blocks]
#    1686         tot_items = sum(b.shape[0] for b in blocks)
# -> 1687         raise construction_error(tot_items, blocks[0].shape[1:], axes, e)
#    1688
#    1689
#
# ValueError: Empty data passed with indices specified.
