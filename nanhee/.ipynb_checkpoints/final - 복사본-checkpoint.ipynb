# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# !pip install xgboost
# !pip install lightgbm
# !pip install imblearn
# !pip install borutashap
# !pip install eli5

# %%
time_table = pd.read_csv('Survival_time_event.csv', index_col=0)
clinic_table = pd.read_csv('Clinical_Variables.csv', index_col=0)
genetic_table = pd.read_csv('Genetic_alterations.csv', index_col=0)
survival_treatment_table = pd.read_csv('newLabel.csv', index_col=0)

# %%
'''
Correlating numerical features of Time data

- outlier value drop
'''

print('outlier of time: ')
print(time_table.loc[time_table['time'] < 0, 'time'], end='\n\n')

time_table_outlier = time_table.copy()
time_table_outlier.loc[time_table_outlier['time'] < 0, 'time'] = abs(time_table_outlier.loc[time_table_outlier['time'] < 0, 'time'])
print(time_table_outlier.describe(), end='\n\n')
# Out:
# outlier of time:
# 905   -7.945621
# Name: time, dtype: float64
#
#               time        event
# count  1000.000000  1000.000000
# mean     51.876125     0.891000
# std      22.122689     0.311795
# min       7.070708     0.000000
# 25%      37.401307     1.000000
# 50%      47.064712     1.000000
# 75%      60.966476     1.000000
# max     217.078908     1.000000

# %%
'''
Correlating numerical features of Clinic data

- outlier value drop
'''

clinic_table_outlier = clinic_table.copy()

# drop outlier
for col in clinic_table_outlier.columns:
    for outlier in range(10,13):
        clinic_table_outlier = clinic_table_outlier.replace(outlier, 9)

# visualize
for col in clinic_table_outlier.columns:
    print('#', col)
    print(clinic_table_outlier[col].value_counts())
    print('-'*20)
# Out:
# # Var1
# 2    235
# 3    204
# 1    171
# 4    139
# 5     95
# 0     57
# 6     50
# 7     27
# 8     13
# 9      9
# Name: Var1, dtype: int64
# --------------------
# # Var2
# 3    221
# 2    218
# 4    163
# 1    113
# 5    109
# 6     65
# 0     48
# 7     30
# 9     20
# 8     13
# Name: Var2, dtype: int64
# --------------------
# # Var3
# 2    260
# 3    196
# 1    156
# 4    130
# 5     97
# 0     55
# 6     55
# 7     23
# 8     16
# 9     12
# Name: Var3, dtype: int64
# --------------------
# # Var4
# 2    242
# 3    195
# 1    150
# 4    140
# 5    106
# 6     67
# 0     36
# 7     32
# 8     16
# 9     16
# Name: Var4, dtype: int64
# --------------------
# # Var5
# 2    247
# 3    223
# 4    161
# 5    124
# 1     76
# 6     63
# 7     41
# 0     28
# 9     19
# 8     18
# Name: Var5, dtype: int64
# --------------------
# # Var6
# 2    240
# 3    212
# 4    128
# 1    127
# 5     99
# 6     64
# 0     53
# 7     40
# 8     20
# 9     17
# Name: Var6, dtype: int64
# --------------------
# # Var7
# 1    269
# 2    208
# 3    144
# 0    128
# 4    118
# 5     62
# 6     47
# 7     16
# 8      6
# 9      2
# Name: Var7, dtype: int64
# --------------------
# # Var8
# 1    241
# 2    227
# 3    171
# 0    127
# 4    101
# 5     69
# 6     30
# 7     20
# 8     10
# 9      4
# Name: Var8, dtype: int64
# --------------------
# # Var9
# 2    250
# 1    235
# 3    157
# 0    135
# 4    100
# 5     57
# 6     33
# 7     22
# 9      6
# 8      5
# Name: Var9, dtype: int64
# --------------------
# # Var10
# 1    287
# 2    205
# 3    156
# 0    114
# 4    108
# 5     62
# 6     40
# 7     18
# 8      5
# 9      5
# Name: Var10, dtype: int64
# --------------------

# %%
'''
Correlating numerical features of Clinic data

- normalization
'''

clinic_table_normalization = clinic_table_outlier.copy()

# normalization
for col in clinic_table_normalization.columns:
    clinic_table_normalization[col] = (clinic_table_normalization[col] + 1)/10.0
    
# visualize
for col in clinic_table_normalization.columns:
    print('#', col)
    print(clinic_table_normalization[col].value_counts())
    print('-'*20)
# Out:
# # Var1
# 0.3    235
# 0.4    204
# 0.2    171
# 0.5    139
# 0.6     95
# 0.1     57
# 0.7     50
# 0.8     27
# 0.9     13
# 1.0      9
# Name: Var1, dtype: int64
# --------------------
# # Var2
# 0.4    221
# 0.3    218
# 0.5    163
# 0.2    113
# 0.6    109
# 0.7     65
# 0.1     48
# 0.8     30
# 1.0     20
# 0.9     13
# Name: Var2, dtype: int64
# --------------------
# # Var3
# 0.3    260
# 0.4    196
# 0.2    156
# 0.5    130
# 0.6     97
# 0.1     55
# 0.7     55
# 0.8     23
# 0.9     16
# 1.0     12
# Name: Var3, dtype: int64
# --------------------
# # Var4
# 0.3    242
# 0.4    195
# 0.2    150
# 0.5    140
# 0.6    106
# 0.7     67
# 0.1     36
# 0.8     32
# 0.9     16
# 1.0     16
# Name: Var4, dtype: int64
# --------------------
# # Var5
# 0.3    247
# 0.4    223
# 0.5    161
# 0.6    124
# 0.2     76
# 0.7     63
# 0.8     41
# 0.1     28
# 1.0     19
# 0.9     18
# Name: Var5, dtype: int64
# --------------------
# # Var6
# 0.3    240
# 0.4    212
# 0.5    128
# 0.2    127
# 0.6     99
# 0.7     64
# 0.1     53
# 0.8     40
# 0.9     20
# 1.0     17
# Name: Var6, dtype: int64
# --------------------
# # Var7
# 0.2    269
# 0.3    208
# 0.4    144
# 0.1    128
# 0.5    118
# 0.6     62
# 0.7     47
# 0.8     16
# 0.9      6
# 1.0      2
# Name: Var7, dtype: int64
# --------------------
# # Var8
# 0.2    241
# 0.3    227
# 0.4    171
# 0.1    127
# 0.5    101
# 0.6     69
# 0.7     30
# 0.8     20
# 0.9     10
# 1.0      4
# Name: Var8, dtype: int64
# --------------------
# # Var9
# 0.3    250
# 0.2    235
# 0.4    157
# 0.1    135
# 0.5    100
# 0.6     57
# 0.7     33
# 0.8     22
# 1.0      6
# 0.9      5
# Name: Var9, dtype: int64
# --------------------
# # Var10
# 0.2    287
# 0.3    205
# 0.4    156
# 0.1    114
# 0.5    108
# 0.6     62
# 0.7     40
# 0.8     18
# 0.9      5
# 1.0      5
# Name: Var10, dtype: int64
# --------------------

# %%
'''
Correlating numerical features of Genetic data

- normalization
'''
genetic_table_normalization = genetic_table.copy()

# normalization
for col in genetic_table_normalization.columns:
    genetic_table_normalization[col] -= 0.5
    
    
print(genetic_table_normalization.head(10))
# Out:
#     G1   G2   G3   G4   G5   G6   G7   G8   G9  G10  ...  G291  G292  G293  \
# 0 -0.5  0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5  ...  -0.5  -0.5  -0.5
# 1 -0.5  0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5  ...  -0.5  -0.5  -0.5
# 2 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5  ...  -0.5  -0.5  -0.5
# 3 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5  0.5 -0.5  0.5  ...  -0.5   0.5  -0.5
# 4 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5  ...  -0.5  -0.5  -0.5
# 5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5  ...  -0.5  -0.5  -0.5
# 6 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5  ...  -0.5  -0.5  -0.5
# 7 -0.5 -0.5 -0.5  0.5 -0.5 -0.5 -0.5 -0.5 -0.5  0.5  ...  -0.5  -0.5  -0.5
# 8 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5  ...  -0.5  -0.5  -0.5
# 9 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5  ...  -0.5  -0.5  -0.5
#
#    G294  G295  G296  G297  G298  G299  G300
# 0  -0.5  -0.5  -0.5  -0.5  -0.5  -0.5  -0.5
# 1  -0.5  -0.5  -0.5  -0.5  -0.5  -0.5  -0.5
# 2  -0.5  -0.5  -0.5  -0.5  -0.5  -0.5  -0.5
# 3   0.5  -0.5  -0.5  -0.5  -0.5  -0.5  -0.5
# 4  -0.5  -0.5  -0.5  -0.5  -0.5  -0.5   0.5
# 5  -0.5  -0.5  -0.5  -0.5  -0.5  -0.5  -0.5
# 6  -0.5  -0.5   0.5  -0.5  -0.5  -0.5  -0.5
# 7  -0.5  -0.5   0.5   0.5  -0.5  -0.5  -0.5
# 8  -0.5  -0.5  -0.5  -0.5  -0.5  -0.5  -0.5
# 9  -0.5  -0.5  -0.5  -0.5  -0.5  -0.5  -0.5
#
# [10 rows x 300 columns]

# %%
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, ExtraTreesClassifier
from sklearn.metrics import accuracy_score
import lightgbm as lgb

# %%
def TestML(model,selected_genetic):
    train_acc = []
    test_acc = []
    for i in range(20):
        genetic_10 = genetic_table_normalization.copy()
        genetic_10 = genetic_10[selected_genetic]

        input_dataset = pd.concat([survival_treatment_table, time_table_outlier, clinic_table_normalization ,genetic_10], axis=1)
        input_dataset = input_dataset.drop(['event'], axis=1)

        all_index = np.arange(1000)
        train_data, test_data = input_dataset.iloc[all_index[:800],:], input_dataset.iloc[all_index[800:1000],:]
        X_train = train_data.drop(['newlabel'], axis=1)
        Y_train = train_data['newlabel']

        X_test = test_data.drop(['newlabel'], axis=1)
        Y_test = test_data['newlabel']

        model.fit(X_train, Y_train)
        train_acc.append(np.round(model.score(X_train, Y_train) * 100, 10))
        
        Y_pred = model.predict(X_test)
        test_acc.append(np.round(accuracy_score(Y_test, Y_pred), 10))
        
        
    print('## Train 정확도: ', np.round(np.max(train_acc), 3), np.round(np.min(train_acc), 3))
    print('## Test 정확도: ', np.round(np.max(test_acc),3), np.round(np.min(test_acc),3))
    print()
    
    return train_acc, test_acc

# %%
test_model1 = RandomForestClassifier(n_estimators=60)
test_model2 = lgb.LGBMClassifier(n_estimators=30,num_leaves=64,n_jobs=-1,boost_from_average=False)

# %%
'''
20번만 돌린 경우

'''
selected_genetic = ['G211', 'G179', 'G80', 'G27', 'G147', 'G139', 'G242', 'G264', 'G290', 'G130']

print('## test_model1 (Train accuracy가 100인 경우의 모델)')
TestML(test_model1, selected_genetic)

print('## test_model2 (Train accuracy가 100이 아닌 경우의 모델)')
TestML(test_model2, selected_genetic)
# Out:
# ## test_model1 (Train accuracy가 100인 경우의 모델)
# ## Train 정확도:  100.0 100.0
# ## Test 정확도:  0.64 0.55
#
# ## test_model2 (Train accuracy가 100이 아닌 경우의 모델)
# ## Train 정확도:  92.75 92.75
# ## Test 정확도:  0.63 0.63

# %%
'''
20번 돌린 것을 100번 돌린 경우

'''
selected_genetic = ['G211', 'G179', 'G80', 'G27', 'G147', 'G139', 'G242', 'G264', 'G290', 'G130']


print('## test_model1 (Train accuracy가 100인 경우의 모델)')
train_result, test_result = [], []
for i in range(100):
    tmp1, tmp2 = TestML(test_model1, selected_genetic)
    train_result.extend(tmp1)
    test_result.extend(tmp2)
    
print('## Train 정확도: ', np.round(np.mean(train_result), 3))
print('## Test 정확도: ', np.round(np.mean(test_result),3))


print('## test_model2 (Train accuracy가 100이 아닌 경우의 모델)')
train_result, test_result = [], []
for i in range(100):
    tmp1, tmp2 = TestML(test_model2, selected_genetic)
    train_result.extend(tmp1)
    test_result.extend(tmp2)
    
print('## Train 정확도: ', np.round(np.mean(train_result), 3))
print('## Test 정확도: ', np.round(np.mean(test_result),3))
# Out:
# ## test_model1 (Train accuracy가 100인 경우의 모델)

# %%
genetic = ['G'+str(i) for i in range(1,301)]

# %%
import random

# print(random.choices(genetic, k=10))

# %%
over_genetic = []
random_genetic_list = []

for i in range(100):
    test_genetic = random.sample(genetic, 10)
    print('## 임의의 10개 유전자: ', test_genetic)
    random_genetic_list.extend(test_genetic)
    
    train_accuracy, test_accuracy = TestML(test_model1, test_genetic)

    if np.max(test_accuracy) >= 0.65 or np.min(test_accuracy) >= 0.565:
        print('-----------------Over!-----------------', end='\n\n\n')
        if np.max(test_accuracy) >= 0.65 and np.min(test_accuracy) >= 0.565:
            whatover = 'max&min'
        elif np.max(test_accuracy) >= 0.65:
            whatover = 'max'
        elif np.min(test_accuracy) >= 0.56:
            whatover = 'min'
        over_genetic.append([test_genetic,whatover])
# Out:
# ## 임의의 10개 유전자:  ['G29', 'G157', 'G273', 'G178', 'G195', 'G214', 'G93', 'G67', 'G201', 'G142']
# ## Train 정확도:  100.0 100.0
# ## Test 정확도:  0.605 0.53
#
# ## 임의의 10개 유전자:  ['G270', 'G229', 'G46', 'G217', 'G279', 'G221', 'G258', 'G136', 'G15', 'G21']
# ## Train 정확도:  100.0 100.0
# ## Test 정확도:  0.625 0.51
#
# ## 임의의 10개 유전자:  ['G100', 'G214', 'G40', 'G151', 'G76', 'G159', 'G105', 'G23', 'G290', 'G114']
# ## Train 정확도:  100.0 100.0
# ## Test 정확도:  0.62 0.535
#
# ## 임의의 10개 유전자:  ['G126', 'G90', 'G294', 'G34', 'G96', 'G151', 'G264', 'G98', 'G30', 'G82']
# ## Train 정확도:  100.0 100.0
# ## Test 정확도:  0.61 0.535
#
# ## 임의의 10개 유전자:  ['G81', 'G65', 'G144', 'G294', 'G20', 'G264', 'G162', 'G58', 'G206', 'G170']
# ## Train 정확도:  100.0 100.0
# ## Test 정확도:  0.61 0.54
#
# ## 임의의 10개 유전자:  ['G46', 'G15', 'G54', 'G16', 'G171', 'G144', 'G154', 'G183', 'G12', 'G296']
# ## Train 정확도:  100.0 100.0
# ## Test 정확도:  0.615 0.555
#
# ## 임의의 10개 유전자:  ['G201', 'G239', 'G111', 'G113', 'G169', 'G144', 'G290', 'G237', 'G266', 'G25']
# ## Train 정확도:  100.0 100.0
# ## Test 정확도:  0.61 0.545
#
# ## 임의의 10개 유전자:  ['G52', 'G130', 'G243', 'G102', 'G233', 'G123', 'G83', 'G38', 'G143', 'G260']
# ## Train 정확도:  100.0 100.0
# ## Test 정확도:  0.605 0.535
#
# ## 임의의 10개 유전자:  ['G82', 'G155', 'G165', 'G151', 'G72', 'G27', 'G228', 'G68', 'G119', 'G194']
# ## Train 정확도:  100.0 100.0
# ## Test 정확도:  0.61 0.56
#
# ## 임의의 10개 유전자:  ['G286', 'G198', 'G156', 'G175', 'G103', 'G129', 'G73', 'G140', 'G33', 'G123']
# ## Train 정확도:  100.0 100.0
# ## Test 정확도:  0.62 0.525
#
# ## 임의의 10개 유전자:  ['G151', 'G196', 'G147', 'G52', 'G83', 'G191', 'G24', 'G156', 'G48', 'G280']
# ## Train 정확도:  100.0 100.0
# ## Test 정확도:  0.595 0.535
#
# ## 임의의 10개 유전자:  ['G41', 'G192', 'G110', 'G277', 'G254', 'G94', 'G22', 'G80', 'G208', 'G174']
# ## Train 정확도:  100.0 100.0
# ## Test 정확도:  0.605 0.545
#
# ## 임의의 10개 유전자:  ['G277', 'G203', 'G251', 'G209', 'G264', 'G48', 'G160', 'G63', 'G181', 'G219']
# ## Train 정확도:  100.0 100.0
# ## Test 정확도:  0.62 0.54
#
# ## 임의의 10개 유전자:  ['G182', 'G86', 'G255', 'G135', 'G91', 'G292', 'G146', 'G44', 'G251', 'G97']
# ## Train 정확도:  100.0 100.0
# ## Test 정확도:  0.6 0.55
#
# ## 임의의 10개 유전자:  ['G165', 'G235', 'G108', 'G33', 'G19', 'G62', 'G279', 'G227', 'G116', 'G35']
# ## Train 정확도:  100.0 100.0
# ## Test 정확도:  0.595 0.55
#
# ## 임의의 10개 유전자:  ['G172', 'G281', 'G54', 'G167', 'G168', 'G122', 'G204', 'G161', 'G254', 'G222']
# ## Train 정확도:  100.0 100.0
# ## Test 정확도:  0.615 0.56
#
# ## 임의의 10개 유전자:  ['G49', 'G94', 'G136', 'G146', 'G46', 'G10', 'G198', 'G254', 'G223', 'G23']
# ## Train 정확도:  100.0 100.0
# ## Test 정확도:  0.595 0.545
#
# ## 임의의 10개 유전자:  ['G69', 'G14', 'G93', 'G63', 'G196', 'G19', 'G268', 'G8', 'G140', 'G253']
# ## Train 정확도:  100.0 100.0
# ## Test 정확도:  0.605 0.545
#
# ## 임의의 10개 유전자:  ['G38', 'G174', 'G227', 'G250', 'G187', 'G181', 'G91', 'G60', 'G70', 'G268']
# ## Train 정확도:  100.0 100.0
# ## Test 정확도:  0.605 0.53
#
# ## 임의의 10개 유전자:  ['G164', 'G38', 'G275', 'G17', 'G293', 'G286', 'G32', 'G8', 'G219', 'G154']
# ## Train 정확도:  100.0 99.875
# ## Test 정확도:  0.615 0.545
#
# ## 임의의 10개 유전자:  ['G148', 'G207', 'G186', 'G196', 'G283', 'G72', 'G103', 'G39', 'G149', 'G262']
# ## Train 정확도:  100.0 99.875
# ## Test 정확도:  0.605 0.53
#
# ## 임의의 10개 유전자:  ['G29', 'G82', 'G155', 'G229', 'G131', 'G19', 'G63', 'G42', 'G226', 'G244']
# ## Train 정확도:  100.0 99.875
# ## Test 정확도:  0.605 0.53
#
# ## 임의의 10개 유전자:  ['G104', 'G90', 'G53', 'G266', 'G106', 'G126', 'G260', 'G89', 'G70', 'G116']
# ## Train 정확도:  100.0 100.0
# ## Test 정확도:  0.625 0.545
#
# ## 임의의 10개 유전자:  ['G191', 'G172', 'G132', 'G62', 'G215', 'G108', 'G150', 'G110', 'G294', 'G281']
# ## Train 정확도:  100.0 99.875
# ## Test 정확도:  0.605 0.525
#
# ## 임의의 10개 유전자:  ['G203', 'G155', 'G95', 'G197', 'G128', 'G144', 'G80', 'G269', 'G133', 'G58']
# ## Train 정확도:  100.0 99.875
# ## Test 정확도:  0.62 0.555
#
# ## 임의의 10개 유전자:  ['G268', 'G184', 'G115', 'G237', 'G29', 'G275', 'G101', 'G107', 'G166', 'G158']
# ## Train 정확도:  100.0 100.0
# ## Test 정확도:  0.605 0.555
#
# ## 임의의 10개 유전자:  ['G256', 'G242', 'G167', 'G292', 'G27', 'G150', 'G28', 'G69', 'G273', 'G41']
# ## Train 정확도:  100.0 100.0
# ## Test 정확도:  0.63 0.54
#
# ## 임의의 10개 유전자:  ['G103', 'G112', 'G31', 'G276', 'G290', 'G270', 'G188', 'G166', 'G154', 'G3']
# ## Train 정확도:  100.0 99.875
# ## Test 정확도:  0.595 0.52
#
# ## 임의의 10개 유전자:  ['G49', 'G192', 'G36', 'G134', 'G137', 'G15', 'G282', 'G4', 'G20', 'G106']
# ## Train 정확도:  100.0 99.875
# ## Test 정확도:  0.615 0.545
#
# ## 임의의 10개 유전자:  ['G244', 'G208', 'G140', 'G10', 'G109', 'G139', 'G272', 'G2', 'G35', 'G202']
# ## Train 정확도:  100.0 100.0
# ## Test 정확도:  0.635 0.56
#
# ## 임의의 10개 유전자:  ['G132', 'G64', 'G291', 'G11', 'G172', 'G73', 'G231', 'G5', 'G228', 'G13']
# ## Train 정확도:  100.0 100.0
# ## Test 정확도:  0.605 0.55
#
# ## 임의의 10개 유전자:  ['G248', 'G35', 'G173', 'G103', 'G5', 'G97', 'G116', 'G8', 'G269', 'G239']
# ## Train 정확도:  100.0 100.0
# ## Test 정확도:  0.63 0.555
#
# ## 임의의 10개 유전자:  ['G267', 'G23', 'G184', 'G166', 'G99', 'G274', 'G193', 'G124', 'G283', 'G42']
# ## Train 정확도:  100.0 100.0
# ## Test 정확도:  0.61 0.545
#
# ## 임의의 10개 유전자:  ['G290', 'G244', 'G6', 'G197', 'G50', 'G60', 'G78', 'G242', 'G200', 'G190']
# ## Train 정확도:  100.0 100.0
# ## Test 정확도:  0.605 0.545
#
# ## 임의의 10개 유전자:  ['G123', 'G274', 'G154', 'G1', 'G231', 'G95', 'G183', 'G57', 'G66', 'G31']
# ## Train 정확도:  100.0 100.0
# ## Test 정확도:  0.64 0.56
#
# ## 임의의 10개 유전자:  ['G293', 'G112', 'G185', 'G288', 'G16', 'G186', 'G254', 'G294', 'G256', 'G23']
# ## Train 정확도:  100.0 100.0
# ## Test 정확도:  0.595 0.545
#
# ## 임의의 10개 유전자:  ['G28', 'G7', 'G16', 'G48', 'G246', 'G31', 'G239', 'G183', 'G136', 'G202']
# ## Train 정확도:  100.0 99.875
# ## Test 정확도:  0.6 0.54
#
# ## 임의의 10개 유전자:  ['G61', 'G42', 'G258', 'G82', 'G157', 'G57', 'G121', 'G236', 'G79', 'G163']
# ## Train 정확도:  100.0 99.875
# ## Test 정확도:  0.615 0.55
#
# ## 임의의 10개 유전자:  ['G40', 'G35', 'G245', 'G226', 'G103', 'G44', 'G300', 'G168', 'G266', 'G139']
# ## Train 정확도:  100.0 99.875
# ## Test 정확도:  0.615 0.555
#
# ## 임의의 10개 유전자:  ['G146', 'G58', 'G176', 'G99', 'G56', 'G74', 'G114', 'G127', 'G26', 'G266']
# ## Train 정확도:  100.0 100.0
# ## Test 정확도:  0.625 0.545
#
# ## 임의의 10개 유전자:  ['G219', 'G162', 'G117', 'G252', 'G102', 'G151', 'G292', 'G159', 'G246', 'G263']
# ## Train 정확도:  100.0 100.0
# ## Test 정확도:  0.605 0.55
#
# ## 임의의 10개 유전자:  ['G52', 'G190', 'G259', 'G124', 'G103', 'G172', 'G208', 'G46', 'G233', 'G277']
# ## Train 정확도:  100.0 100.0
# ## Test 정확도:  0.59 0.53
#
# ## 임의의 10개 유전자:  ['G240', 'G181', 'G34', 'G239', 'G213', 'G297', 'G296', 'G225', 'G268', 'G39']
# ## Train 정확도:  100.0 100.0
# ## Test 정확도:  0.605 0.53
#
# ## 임의의 10개 유전자:  ['G92', 'G245', 'G201', 'G137', 'G10', 'G72', 'G202', 'G135', 'G297', 'G185']
# ## Train 정확도:  100.0 100.0
# ## Test 정확도:  0.6 0.52
#
# ## 임의의 10개 유전자:  ['G198', 'G154', 'G158', 'G177', 'G97', 'G268', 'G221', 'G80', 'G159', 'G56']
# ## Train 정확도:  100.0 99.875
# ## Test 정확도:  0.61 0.53
#
# ## 임의의 10개 유전자:  ['G118', 'G39', 'G124', 'G253', 'G182', 'G102', 'G259', 'G3', 'G181', 'G205']
# ## Train 정확도:  100.0 100.0
# ## Test 정확도:  0.615 0.545
#
# ## 임의의 10개 유전자:  ['G33', 'G169', 'G181', 'G49', 'G59', 'G136', 'G220', 'G41', 'G249', 'G124']
# ## Train 정확도:  100.0 100.0
# ## Test 정확도:  0.59 0.515
#
# ## 임의의 10개 유전자:  ['G221', 'G24', 'G89', 'G46', 'G139', 'G200', 'G260', 'G69', 'G49', 'G50']
# ## Train 정확도:  100.0 100.0
# ## Test 정확도:  0.6 0.53
#
# ## 임의의 10개 유전자:  ['G74', 'G262', 'G291', 'G257', 'G26', 'G214', 'G58', 'G42', 'G196', 'G183']
# ## Train 정확도:  100.0 99.875
# ## Test 정확도:  0.6 0.545
#
# ## 임의의 10개 유전자:  ['G293', 'G142', 'G193', 'G184', 'G41', 'G268', 'G280', 'G284', 'G39', 'G151']
# ## Train 정확도:  100.0 100.0
# ## Test 정확도:  0.6 0.55
#
# ## 임의의 10개 유전자:  ['G114', 'G273', 'G31', 'G49', 'G219', 'G28', 'G143', 'G15', 'G157', 'G174']
# ## Train 정확도:  100.0 100.0
# ## Test 정확도:  0.61 0.54
#
# ## 임의의 10개 유전자:  ['G278', 'G186', 'G212', 'G14', 'G134', 'G154', 'G273', 'G11', 'G292', 'G159']
# ## Train 정확도:  100.0 100.0
# ## Test 정확도:  0.605 0.535
#
# ## 임의의 10개 유전자:  ['G108', 'G100', 'G178', 'G193', 'G255', 'G218', 'G291', 'G73', 'G43', 'G161']
# ## Train 정확도:  100.0 100.0
# ## Test 정확도:  0.605 0.545
#
# ## 임의의 10개 유전자:  ['G113', 'G202', 'G78', 'G150', 'G129', 'G183', 'G38', 'G110', 'G261', 'G169']
# ## Train 정확도:  100.0 100.0
# ## Test 정확도:  0.61 0.54
#
# ## 임의의 10개 유전자:  ['G178', 'G154', 'G280', 'G160', 'G216', 'G188', 'G119', 'G199', 'G9', 'G239']
# ## Train 정확도:  100.0 100.0
# ## Test 정확도:  0.615 0.515
#
# ## 임의의 10개 유전자:  ['G75', 'G297', 'G141', 'G76', 'G286', 'G224', 'G32', 'G104', 'G258', 'G150']
# ## Train 정확도:  100.0 100.0
# ## Test 정확도:  0.6 0.54
#
# ## 임의의 10개 유전자:  ['G124', 'G91', 'G274', 'G3', 'G134', 'G153', 'G75', 'G251', 'G230', 'G261']
# ## Train 정확도:  100.0 99.875
# ## Test 정확도:  0.6 0.51
#
# ## 임의의 10개 유전자:  ['G274', 'G215', 'G253', 'G14', 'G55', 'G85', 'G56', 'G30', 'G78', 'G272']
# ## Train 정확도:  100.0 100.0
# ## Test 정확도:  0.615 0.54
#
# ## 임의의 10개 유전자:  ['G290', 'G225', 'G71', 'G262', 'G141', 'G226', 'G75', 'G42', 'G118', 'G70']
# ## Train 정확도:  100.0 100.0
# ## Test 정확도:  0.61 0.55
#
# ## 임의의 10개 유전자:  ['G158', 'G7', 'G142', 'G288', 'G52', 'G4', 'G105', 'G166', 'G83', 'G68']
# ## Train 정확도:  100.0 100.0
# ## Test 정확도:  0.615 0.535
#
# ## 임의의 10개 유전자:  ['G80', 'G19', 'G9', 'G233', 'G37', 'G244', 'G204', 'G245', 'G18', 'G54']
# ## Train 정확도:  100.0 100.0
# ## Test 정확도:  0.625 0.56
#
# ## 임의의 10개 유전자:  ['G55', 'G48', 'G125', 'G113', 'G39', 'G215', 'G297', 'G80', 'G34', 'G173']
# ## Train 정확도:  100.0 100.0
# ## Test 정확도:  0.605 0.56
#
# ## 임의의 10개 유전자:  ['G279', 'G165', 'G237', 'G31', 'G138', 'G61', 'G214', 'G247', 'G101', 'G293']
# ## Train 정확도:  100.0 99.875
# ## Test 정확도:  0.635 0.535
#
# ## 임의의 10개 유전자:  ['G118', 'G99', 'G134', 'G123', 'G234', 'G252', 'G208', 'G205', 'G243', 'G39']
# ## Train 정확도:  100.0 100.0
# ## Test 정확도:  0.625 0.565
#
# -----------------Over!-----------------
#
#
# ## 임의의 10개 유전자:  ['G58', 'G222', 'G13', 'G3', 'G193', 'G7', 'G28', 'G265', 'G176', 'G130']
# ## Train 정확도:  100.0 100.0
# ## Test 정확도:  0.6 0.54
#
# ## 임의의 10개 유전자:  ['G61', 'G74', 'G296', 'G269', 'G87', 'G177', 'G255', 'G21', 'G193', 'G180']
# ## Train 정확도:  100.0 99.875
# ## Test 정확도:  0.625 0.535
#
# ## 임의의 10개 유전자:  ['G109', 'G241', 'G64', 'G14', 'G286', 'G60', 'G282', 'G160', 'G55', 'G83']
# ## Train 정확도:  100.0 100.0
# ## Test 정확도:  0.605 0.54
#
# ## 임의의 10개 유전자:  ['G232', 'G265', 'G168', 'G127', 'G45', 'G50', 'G10', 'G95', 'G19', 'G290']
# ## Train 정확도:  100.0 100.0
# ## Test 정확도:  0.605 0.545
#
# ## 임의의 10개 유전자:  ['G182', 'G52', 'G220', 'G7', 'G190', 'G113', 'G11', 'G299', 'G112', 'G43']
# ## Train 정확도:  100.0 100.0
# ## Test 정확도:  0.62 0.545
#
# ## 임의의 10개 유전자:  ['G57', 'G209', 'G77', 'G82', 'G282', 'G146', 'G55', 'G226', 'G213', 'G128']
# ## Train 정확도:  100.0 100.0
# ## Test 정확도:  0.615 0.545
#
# ## 임의의 10개 유전자:  ['G23', 'G268', 'G9', 'G5', 'G237', 'G300', 'G140', 'G258', 'G297', 'G44']
# ## Train 정확도:  100.0 100.0
# ## Test 정확도:  0.605 0.525
#
# ## 임의의 10개 유전자:  ['G154', 'G163', 'G207', 'G264', 'G256', 'G101', 'G104', 'G108', 'G109', 'G280']
# ## Train 정확도:  100.0 100.0
# ## Test 정확도:  0.605 0.505
#
# ## 임의의 10개 유전자:  ['G202', 'G4', 'G86', 'G292', 'G177', 'G16', 'G288', 'G131', 'G276', 'G187']
# ## Train 정확도:  100.0 100.0
# ## Test 정확도:  0.605 0.525
#
# ## 임의의 10개 유전자:  ['G152', 'G51', 'G162', 'G224', 'G253', 'G219', 'G203', 'G295', 'G290', 'G11']
# ## Train 정확도:  100.0 100.0
# ## Test 정확도:  0.62 0.545
#
# ## 임의의 10개 유전자:  ['G294', 'G13', 'G214', 'G290', 'G265', 'G134', 'G242', 'G85', 'G80', 'G126']
# ## Train 정확도:  100.0 100.0
# ## Test 정확도:  0.615 0.55
#
# ## 임의의 10개 유전자:  ['G178', 'G65', 'G175', 'G79', 'G291', 'G22', 'G248', 'G257', 'G196', 'G21']
# ## Train 정확도:  100.0 99.875
# ## Test 정확도:  0.595 0.53
#
# ## 임의의 10개 유전자:  ['G281', 'G83', 'G3', 'G156', 'G299', 'G186', 'G65', 'G247', 'G10', 'G294']
# ## Train 정확도:  100.0 100.0
# ## Test 정확도:  0.59 0.52
#
# ## 임의의 10개 유전자:  ['G140', 'G169', 'G249', 'G293', 'G206', 'G258', 'G71', 'G247', 'G243', 'G219']
# ## Train 정확도:  100.0 100.0
# ## Test 정확도:  0.585 0.54
#
# ## 임의의 10개 유전자:  ['G69', 'G198', 'G68', 'G85', 'G250', 'G236', 'G52', 'G187', 'G156', 'G114']
# ## Train 정확도:  100.0 100.0
# ## Test 정확도:  0.585 0.535
#
# ## 임의의 10개 유전자:  ['G293', 'G21', 'G175', 'G294', 'G200', 'G126', 'G279', 'G66', 'G73', 'G26']
# ## Train 정확도:  100.0 100.0
# ## Test 정확도:  0.625 0.54
#
# ## 임의의 10개 유전자:  ['G60', 'G161', 'G118', 'G209', 'G6', 'G195', 'G177', 'G62', 'G277', 'G125']
# ## Train 정확도:  100.0 99.875
# ## Test 정확도:  0.615 0.545
#
# ## 임의의 10개 유전자:  ['G221', 'G175', 'G54', 'G241', 'G145', 'G137', 'G168', 'G274', 'G2', 'G150']
# ## Train 정확도:  100.0 100.0
# ## Test 정확도:  0.605 0.55
#
# ## 임의의 10개 유전자:  ['G288', 'G236', 'G143', 'G162', 'G75', 'G227', 'G115', 'G209', 'G114', 'G180']
# ## Train 정확도:  100.0 100.0
# ## Test 정확도:  0.61 0.54
#
# ## 임의의 10개 유전자:  ['G282', 'G53', 'G167', 'G75', 'G87', 'G151', 'G246', 'G35', 'G56', 'G38']
# ## Train 정확도:  100.0 100.0
# ## Test 정확도:  0.6 0.54
#
# ## 임의의 10개 유전자:  ['G244', 'G119', 'G83', 'G178', 'G208', 'G109', 'G253', 'G123', 'G220', 'G71']
# ## Train 정확도:  100.0 100.0
# ## Test 정확도:  0.615 0.555
#
# ## 임의의 10개 유전자:  ['G162', 'G12', 'G78', 'G249', 'G51', 'G145', 'G284', 'G90', 'G123', 'G134']
# ## Train 정확도:  100.0 100.0
# ## Test 정확도:  0.62 0.52
#
# ## 임의의 10개 유전자:  ['G163', 'G282', 'G276', 'G179', 'G165', 'G204', 'G82', 'G150', 'G223', 'G272']
# ## Train 정확도:  100.0 99.875
# ## Test 정확도:  0.615 0.52
#
# ## 임의의 10개 유전자:  ['G173', 'G190', 'G283', 'G140', 'G229', 'G132', 'G194', 'G44', 'G198', 'G175']
# ## Train 정확도:  100.0 100.0
# ## Test 정확도:  0.595 0.53
#
# ## 임의의 10개 유전자:  ['G254', 'G268', 'G255', 'G100', 'G95', 'G234', 'G299', 'G101', 'G17', 'G56']
# ## Train 정확도:  100.0 100.0
# ## Test 정확도:  0.61 0.56
#
# ## 임의의 10개 유전자:  ['G220', 'G71', 'G97', 'G52', 'G293', 'G54', 'G82', 'G96', 'G272', 'G139']
# ## Train 정확도:  100.0 99.875
# ## Test 정확도:  0.615 0.545
#
# ## 임의의 10개 유전자:  ['G33', 'G172', 'G75', 'G40', 'G142', 'G110', 'G39', 'G267', 'G127', 'G141']
# ## Train 정확도:  100.0 100.0
# ## Test 정확도:  0.595 0.52
#
# ## 임의의 10개 유전자:  ['G270', 'G189', 'G227', 'G283', 'G47', 'G181', 'G90', 'G210', 'G256', 'G2']
# ## Train 정확도:  100.0 99.875
# ## Test 정확도:  0.6 0.54
#
# ## 임의의 10개 유전자:  ['G100', 'G223', 'G105', 'G290', 'G173', 'G263', 'G40', 'G214', 'G6', 'G166']
# ## Train 정확도:  100.0 99.875
# ## Test 정확도:  0.61 0.535
#
# ## 임의의 10개 유전자:  ['G111', 'G211', 'G228', 'G220', 'G13', 'G132', 'G115', 'G9', 'G81', 'G181']
# ## Train 정확도:  100.0 100.0
# ## Test 정확도:  0.61 0.545
#
# ## 임의의 10개 유전자:  ['G10', 'G229', 'G51', 'G265', 'G97', 'G222', 'G47', 'G145', 'G118', 'G31']
# ## Train 정확도:  100.0 100.0
# ## Test 정확도:  0.605 0.555
#
# ## 임의의 10개 유전자:  ['G79', 'G170', 'G23', 'G215', 'G144', 'G15', 'G213', 'G235', 'G234', 'G263']
# ## Train 정확도:  100.0 99.875
# ## Test 정확도:  0.6 0.545
#
# ## 임의의 10개 유전자:  ['G50', 'G253', 'G4', 'G15', 'G295', 'G82', 'G26', 'G292', 'G205', 'G277']
# ## Train 정확도:  100.0 100.0
# ## Test 정확도:  0.6 0.54
#
# ## 임의의 10개 유전자:  ['G192', 'G44', 'G262', 'G209', 'G7', 'G75', 'G117', 'G92', 'G28', 'G300']
# ## Train 정확도:  100.0 100.0
# ## Test 정확도:  0.595 0.495
#
# ## 임의의 10개 유전자:  ['G293', 'G206', 'G205', 'G265', 'G111', 'G56', 'G159', 'G299', 'G179', 'G173']
# ## Train 정확도:  100.0 100.0
# ## Test 정확도:  0.595 0.53
#
# ## 임의의 10개 유전자:  ['G208', 'G9', 'G105', 'G84', 'G118', 'G271', 'G70', 'G78', 'G192', 'G229']
# ## Train 정확도:  100.0 100.0
# ## Test 정확도:  0.61 0.54

# %%
print(over_genetic)
# Out:
# [[['G118', 'G99', 'G134', 'G123', 'G234', 'G252', 'G208', 'G205', 'G243', 'G39'], 'min']]

# %%
print(len(over_genetic))
# Out:
# 1

# %%
over_genetic_results = np.array(over_genetic)
pd.set_option('display.max_colwidth', -1)
display(pd.DataFrame(over_genetic_results, columns=['RandomSet', 'Test Result']))
# Out:
# <ipython-input-41-8cd00849c86a>:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   over_genetic_results = np.array(over_genetic)
# <ipython-input-41-8cd00849c86a>:2: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)
#                                                     RandomSet Test Result
# 0  [G118, G99, G134, G123, G234, G252, G208, G205, G243, G39]  min

# %%
def sort_genetic_table(genetic_list):
    np_rgl = np.array(genetic_list)
    np_rgl = np.char.replace(np_rgl, 'G', '')
    np_rgl = np.array(np_rgl, dtype='int')
    np_rgl = sorted(np_rgl)
    np_rgl = np.array(np_rgl, dtype='str')
    np_rgl = np.char.add(np.array(['G']*np_rgl.shape[0]),np_rgl)

    return np_rgl.tolist()

# %%
fig, ax = plt.subplots()

kwargs = dict(alpha=0.3, bins=300)

sorted_random_genetic_list = sort_genetic_table(random_genetic_list)
ax.hist(sorted_random_genetic_list, **dict(alpha=0.3, bins=300), color='r', label='random genetic table')
ax.hist(selected_genetic, **dict(alpha=1, bins=300), color='g', label='selected genetic table')
ax.set(title='Frequency Histogram of Random genetic table', ylabel='Frequency')
fig.savefig('Frequency Histogram of Random genetic table - Acc_100.png', dpi = 200)
plt.show()

# %%
from collections import Counter
from tabulate import tabulate

sorted_random_genetic_dict = Counter(sorted_random_genetic_list)
sorted_random_genetic_df = pd.DataFrame.from_dict(sorted_random_genetic_dict, orient='index').rename(columns={0:'Count'})
# sorted_random_genetic_df.style

print(tabulate(sorted_random_genetic_df, headers = 'keys', tablefmt='pretty'))

# %%
over_genetic = []
random_genetic_list = []

for i in range(100):
    test_genetic = random.sample(genetic, 10)
    print('## 임의의 10개 유전자: ', test_genetic)
    random_genetic_list.append(*test_genetic)
    
    train_accuracy, test_accuracy = TestML(test_model2, test_genetic)
    if train_accuracy >= 93.25 or test_accuracy >= 0.635:
        print('-----------------Over!-----------------', end='\n\n\n')
        if train_accuracy > 93.25 and test_accuracy > 0.635:
            whatover = 'train&test'
        elif train_accuracy > 93.25:
            whatover = 'train'
        elif test_accuracy > 0.635:
            whatover = 'test'
        over_genetic.append([test_genetic,whatover])

# %%
print(over_genetic)
print(len(over_genetic))
